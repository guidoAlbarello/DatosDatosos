# %%
# %matplotlib inline

import sklearn
from sklearn.feature_selection import SelectKBest




import gc
import datetime as dt


import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from collections import defaultdict

plt.style.use('default') # Make the graphs a bit prettier
plt.rcParams['figure.figsize'] = (15, 5)

# %%
station = pd.read_csv('station.csv', low_memory=False)
trip_test = pd.read_csv('trip_test.csv', low_memory=False)
trip_train = pd.read_csv('trip_train.csv', low_memory=False)
weather = pd.read_csv('weather.csv', low_memory=False)

# %%
trip_train = pd.merge(trip_train, station[['id', 'lat', 'long']], left_on='start_station_id', right_on= 'id' ,how='left')
trip_test = pd.merge(trip_test, station[['id', 'lat', 'long']], left_on='start_station_id', right_on= 'id' ,how='left')

# %%
trip_train.drop('id_y', axis=1, inplace=True)
trip_train.rename(columns={'id_x' : 'id', 'lat': 'start_station_lat','long': 'start_station_long'}, inplace=True)

trip_test.drop('id_y', axis=1, inplace=True)
trip_test.rename(columns={'id_x' : 'id', 'lat': 'start_station_lat','long': 'start_station_long'}, inplace=True)

# %%
trip_train = pd.merge(trip_train, station[['id', 'lat', 'long']], left_on='end_station_id', right_on= 'id' ,how='left')

trip_test = pd.merge(trip_test, station[['id', 'lat', 'long']], left_on='end_station_id', right_on= 'id' ,how='left')

# %%
trip_train.drop('id_y', axis=1, inplace=True)
trip_train.rename(columns={'id_x' : 'id', 'lat': 'end_station_lat','long': 'end_station_long'}, inplace=True)

trip_test.drop('id_y', axis=1, inplace=True)
trip_test.rename(columns={'id_x' : 'id', 'lat': 'end_station_lat','long': 'end_station_long'}, inplace=True)

# %%
trip_train['start_station_lat'] = trip_train[pd.to_numeric(trip_train.start_station_lat, errors='coerce').notnull()]['start_station_lat']
trip_train['start_station_long'] = trip_train[pd.to_numeric(trip_train.start_station_long, errors='coerce').notnull()]['start_station_long']
trip_train['end_station_lat'] = trip_train[pd.to_numeric(trip_train.end_station_lat, errors='coerce').notnull()]['end_station_lat']
trip_train['end_station_long'] = trip_train[pd.to_numeric(trip_train.end_station_long, errors='coerce').notnull()]['end_station_long']

trip_test['start_station_lat'] = trip_test[pd.to_numeric(trip_test.start_station_lat, errors='coerce').notnull()]['start_station_lat']
trip_test['start_station_long'] = trip_test[pd.to_numeric(trip_test.start_station_long, errors='coerce').notnull()]['start_station_long']
trip_test['end_station_lat'] = trip_test[pd.to_numeric(trip_test.end_station_lat, errors='coerce').notnull()]['end_station_lat']
trip_test['end_station_long'] = trip_test[pd.to_numeric(trip_test.end_station_long, errors='coerce').notnull()]['end_station_long']

# %%
trip_test
# Out:
#             id        start_date  \
# 0       504737  10/18/2014 11:25
# 1       530846   11/5/2014 13:00
# 2       813140   6/18/2015 17:34
# 3       897674    8/20/2015 7:06
# 4       322830    6/13/2014 8:46
# 5       487841   10/7/2014 21:41
# 6       677808   3/11/2015 18:09
# 7       704449   3/30/2015 17:29
# 8       833587    7/5/2015 11:54
# 9       420411   8/22/2014 13:30
# 10      354777    7/8/2014 14:05
# 11       17809   9/11/2013 13:17
# 12      854667   7/20/2015 19:45
# 13      673325     3/9/2015 8:47
# 14      729900    4/17/2015 9:28
# 15        4485   8/29/2013 13:16
# 16      349394     7/3/2014 8:03
# 17      784460   5/28/2015 13:27
# 119985         -122.388013        37.776617       -122.395260
# 119986         -122.400862        37.794139       -122.394434
# 119987         -122.417385        37.786305       -122.404966
# 119988         -122.402717        37.776617       -122.395260
# 119989         -122.399051        37.787152       -122.388013
# 119990         -122.395470        37.781752       -122.405127
# 119991         -122.394203        37.804770       -122.403234
# 119992         -122.395470        37.789756       -122.394643
# 119993         -122.418954        37.781332       -122.418603
# 119994         -122.395470        37.781752       -122.405127
# 119995         -122.394203        37.795392       -122.394203
# 119996         -121.901782        37.333988       -121.894902
# 119997         -122.399051        37.776600       -122.395470
#
# [119998 rows x 14 columns]

# %%
from math import radians, cos, sin, asin, sqrt

#distancia entre dos estaciones 
def distanciaEntreEstaciones(long1, lat1, long2, lat2):
    long1, lat1, long2, lat2 = map(radians, [long1, lat1, long2, lat2])
    dLong = long2 - long1 
    dLat = lat2 - lat1 
    a = sin(dLat/2)**2 + cos(lat1) * cos(lat2) * sin(dLong/2)**2
    c = 2 * asin(sqrt(a)) 
    km = 6367 * c
    return km 

distanciaTrain = trip_train.apply(lambda x: distanciaEntreEstaciones(x[11], x[12], x[13], x[14]), axis = 1)
trip_train['distancia_entre_estaciones'] = distanciaTrain

distanciaTest = trip_test.apply(lambda x: distanciaEntreEstaciones(x[10], x[11], x[12], x[13]), axis = 1)
trip_test['distancia_entre_estaciones'] = distanciaTest

# %%
del trip_train['start_station_lat']
del trip_train['start_station_long']
del trip_train['end_station_lat']
del trip_train['end_station_long']

del trip_test['start_station_lat']
del trip_test['start_station_long']
del trip_test['end_station_lat']
del trip_test['end_station_long']

# %%
fechasStart = trip_train['start_date'].map(lambda x: (x.split(' ')[0]))
trip_train['startDate'] =  fechasStart
fechasEnd = trip_train['end_date'].map(lambda x: (x.split(' ')[0]))
trip_train['endDate'] =  fechasEnd

fechasStartTest = trip_test['start_date'].map(lambda x: (x.split(' ')[0]))
trip_test['startDate'] =  fechasStartTest
fechasEndTest = trip_test['end_date'].map(lambda x: (x.split(' ')[0]))
trip_test['endDate'] =  fechasEndTest

# %%
#separamos la fecha por / y eliminamos todo lo q hay mas a la derecha del espacio despues del año
fechas = trip_train['start_date'].map(lambda x: (x.split('/')[0], x.split('/')[1], x.split('/')[2].split(' ')[0]))

#convertimos cada tupla de año mes dia a dia de semana ylo guardamos en un nuevo campo 
trip_train['startDate_weekday'] = fechas.map(lambda x: dt.date(int(x[2]),int(x[0]),int(x[1])).strftime("%A"))

#separamos la fecha por / y eliminamos todo lo q hay mas a la derecha del espacio despues del año
fechas = trip_train['end_date'].map(lambda x: (x.split('/')[0], x.split('/')[1], x.split('/')[2].split(' ')[0]))

#convertimos cada tupla de año mes dia a dia de semana ylo guardamos en un nuevo campo 
trip_train['endDate_weekday'] = fechas.map(lambda x: dt.date(int(x[2]),int(x[0]),int(x[1])).strftime("%A"))

# %%
#separamos la fecha por / y eliminamos todo lo q hay mas a la derecha del espacio despues del año
fechas = trip_test['start_date'].map(lambda x: (x.split('/')[0], x.split('/')[1], x.split('/')[2].split(' ')[0]))

#convertimos cada tupla de año mes dia a dia de semana ylo guardamos en un nuevo campo 
trip_test['startDate_weekday'] = fechas.map(lambda x: dt.date(int(x[2]),int(x[0]),int(x[1])).strftime("%A"))

#separamos la fecha por / y eliminamos todo lo q hay mas a la derecha del espacio despues del año
fechas = trip_test['end_date'].map(lambda x: (x.split('/')[0], x.split('/')[1], x.split('/')[2].split(' ')[0]))

#convertimos cada tupla de año mes dia a dia de semana ylo guardamos en un nuevo campo 
trip_test['endDate_weekday'] = fechas.map(lambda x: dt.date(int(x[2]),int(x[0]),int(x[1])).strftime("%A"))

# %%
#separamos en dos campos nuevos. fecha en formato yyyymmdd y hora del dia en minutos
fechasStart = trip_train['start_date'].map(lambda x: (int(dt.datetime.strptime(x.split(' ')[0], "%m/%d/%Y").strftime("%Y%m%d"))))
horasStart = trip_train['start_date'].map(lambda x: (x.split(' ')[1]))
horasStart = horasStart.map(lambda x: (int(x.split(':')[0]) * 60 *60+ int(x.split(':')[1])*60))

fechasEnd = trip_train['end_date'].map(lambda x: (int(dt.datetime.strptime(x.split(' ')[0], "%m/%d/%Y").strftime("%Y%m%d"))))
horasEnd = trip_train['end_date'].map(lambda x: (x.split(' ')[1]))
horasEnd = horasEnd.map(lambda x: (int(x.split(':')[0]) * 60 *60+ int(x.split(':')[1])*60))

# %%
#separamos en dos campos nuevos. fecha en formato yyyymmdd y hora del dia en minutos
fechasStartTest = trip_test['start_date'].map(lambda x: (int(dt.datetime.strptime(x.split(' ')[0], "%m/%d/%Y").strftime("%Y%m%d"))))
horasStartTest = trip_test['start_date'].map(lambda x: (x.split(' ')[1]))
horasStartTest = horasStartTest.map(lambda x: (int(x.split(':')[0]) * 60 *60+ int(x.split(':')[1])*60))

fechasEndTest = trip_test['end_date'].map(lambda x: (int(dt.datetime.strptime(x.split(' ')[0], "%m/%d/%Y").strftime("%Y%m%d"))))
horasEndTest = trip_test['end_date'].map(lambda x: (x.split(' ')[1]))
horasEndTest = horasEndTest.map(lambda x: (int(x.split(':')[0]) * 60 *60+ int(x.split(':')[1])*60))

# %%
#ver dia y noche como afecta

#separamos la fecha por / y eliminamos todo lo q hay mas a la derecha del espacio despues del año
fechas = trip_train['start_date'].map(lambda x: (x.split('/')[0], x.split('/')[1], x.split('/')[2].split(' ')[0]))

horas = trip_train['start_date'].map(lambda x:x.split('/')[2].split(' ')[1].split(':')[0])
#convertimos cada tupla de año mes dia a dia de semana ylo guardamos en un nuevo campo 

fechas = fechas.map(lambda x: dt.date(int(x[2]),int(x[0]),int(x[1])).strftime("%m"))

i = 0
deNoche = [0] * fechas.size
for line in fechas:
    if(((int(line) < 4) & (int(line) > 0)) | ((int(line) > 9)&(int(line) < 13))):
        if((int(horas[i]) <18) & (int(horas[i]) > 7)):
            deNoche[i] = 0
        else:
            deNoche[i] = 1
    else:
        if((int(horas[i]) <20) & (int(horas[i]) > 6)):
            deNoche[i] = 0
        else:
            deNoche[i] = 1
    i = i + 1 
        
trip_train['startDate_deNoche'] = deNoche

#ver dia y noche como afecta

#separamos la fecha por / y eliminamos todo lo q hay mas a la derecha del espacio despues del año
fechas = trip_train['end_date'].map(lambda x: (x.split('/')[0], x.split('/')[1], x.split('/')[2].split(' ')[0]))

horas = trip_train['end_date'].map(lambda x:x.split('/')[2].split(' ')[1].split(':')[0])
#convertimos cada tupla de año mes dia a dia de semana ylo guardamos en un nuevo campo 

fechas = fechas.map(lambda x: dt.date(int(x[2]),int(x[0]),int(x[1])).strftime("%m"))

i = 0
deNoche = [0] * fechas.size
for line in fechas:
    if(((int(line) < 4) & (int(line) > 0)) | ((int(line) > 9)&(int(line) < 13))):
        if((int(horas[i]) <18) & (int(horas[i]) > 7)):
            deNoche[i] = 0
        else:
            deNoche[i] = 1
    else:
        if((int(horas[i]) <20) & (int(horas[i]) > 6)):
            deNoche[i] = 0
        else:
            deNoche[i] = 1
    i = i + 1 
        
trip_train['endDate_deNoche'] = deNoche

# %%
#ver dia y noche como afecta

#separamos la fecha por / y eliminamos todo lo q hay mas a la derecha del espacio despues del año
fechas = trip_test['start_date'].map(lambda x: (x.split('/')[0], x.split('/')[1], x.split('/')[2].split(' ')[0]))

horas = trip_test['start_date'].map(lambda x:x.split('/')[2].split(' ')[1].split(':')[0])
#convertimos cada tupla de año mes dia a dia de semana ylo guardamos en un nuevo campo 

fechas = fechas.map(lambda x: dt.date(int(x[2]),int(x[0]),int(x[1])).strftime("%m"))

i = 0
deNoche = [0] * fechas.size
for line in fechas:
    if(((int(line) < 4) & (int(line) > 0)) | ((int(line) > 9)&(int(line) < 13))):
        if((int(horas[i]) <18) & (int(horas[i]) > 7)):
            deNoche[i] = 0
        else:
            deNoche[i] = 1
    else:
        if((int(horas[i]) <20) & (int(horas[i]) > 6)):
            deNoche[i] = 0
        else:
            deNoche[i] = 1
    i = i + 1 
        
trip_test['startDate_deNoche'] = deNoche

#ver dia y noche como afecta

#separamos la fecha por / y eliminamos todo lo q hay mas a la derecha del espacio despues del año
fechas = trip_test['end_date'].map(lambda x: (x.split('/')[0], x.split('/')[1], x.split('/')[2].split(' ')[0]))

horas = trip_test['end_date'].map(lambda x:x.split('/')[2].split(' ')[1].split(':')[0])
#convertimos cada tupla de año mes dia a dia de semana ylo guardamos en un nuevo campo 

fechas = fechas.map(lambda x: dt.date(int(x[2]),int(x[0]),int(x[1])).strftime("%m"))

i = 0
deNoche = [0] * fechas.size
for line in fechas:
    if(((int(line) < 4) & (int(line) > 0)) | ((int(line) > 9)&(int(line) < 13))):
        if((int(horas[i]) <18) & (int(horas[i]) > 7)):
            deNoche[i] = 0
        else:
            deNoche[i] = 1
    else:
        if((int(horas[i]) <20) & (int(horas[i]) > 6)):
            deNoche[i] = 0
        else:
            deNoche[i] = 1
    i = i + 1 
        
trip_test['endDate_deNoche'] = deNoche

# %%
weather['zip_code'] = weather['zip_code'].apply(str)

# %%
trip_train = trip_train.merge(weather, left_on=['startDate', 'zip_code'], right_on= ['date', 'zip_code'] ,how='left')
trip_test = trip_test.merge(weather, left_on=['startDate', 'zip_code'], right_on= ['date', 'zip_code'] ,how='left')

# %%
del trip_train['endDate']
del trip_train['startDate']
del trip_train['id']
del trip_train['start_station_name']
del trip_train['end_station_name']
del trip_train['start_date']
del trip_train['end_date']
del trip_train['date']
del trip_train['zip_code']

del trip_test['endDate']
del trip_test['startDate']
del trip_test['id']
del trip_test['start_station_name']
del trip_test['end_station_name']
del trip_test['start_date']
del trip_test['end_date']
del trip_test['date']
del trip_test['zip_code']

# %%
trip_train['start_date'] = fechasStart
trip_train['end_date'] = fechasEnd
trip_train['start_hour'] = horasStart
trip_train['end_hour'] = horasEnd

trip_test['start_date'] = fechasStartTest
trip_test['end_date'] = fechasEndTest
trip_test['start_hour'] = horasStartTest
trip_test['end_hour'] = horasEndTest

# %%
#convertimos subscription_type a 1 y 0 
trip_train['duration'] = trip_train[pd.to_numeric(trip_train.duration, errors='coerce').notnull()]['duration']
subscription_type = trip_train['subscription_type'].map(lambda x: 1 if x == 'Subscriber' else 0)
trip_train['subscription_type'] = subscription_type
trip_train.head()
# Out:
#    duration  start_station_id  end_station_id  bike_id  subscription_type  \
# 0       396                50              60      187                  1
# 1       636                67              46      417                  1
# 2       334                77              62      281                  1
# 3       666                69              55      634                  1
# 4       318                67              39      607                  1
#
#    distancia_entre_estaciones startDate_weekday endDate_weekday  \
# 0                    1.148453          Thursday        Thursday
# 1                    1.794651            Monday          Monday
# 2                    0.569924            Monday          Monday
# 3                    0.788625            Monday          Monday
# 4                    1.084530          Saturday        Saturday
#
#    startDate_deNoche  endDate_deNoche    ...     mean_wind_speed_mph  \
# 0                  0                0    ...                     NaN
# 1                  1                1    ...                     NaN
# 2                  0                0    ...                    10.0
# 3                  0                0    ...                     NaN
# 4                  0                0    ...                     NaN
#
#    max_gust_speed_mph  precipitation_inches  cloud_cover  events  \
# 0                 NaN                   NaN          NaN     NaN
# 1                 NaN                   NaN          NaN     NaN
# 2                25.0                     0          1.0     NaN
# 3                 NaN                   NaN          NaN     NaN
# 4                 NaN                   NaN          NaN     NaN
#
#    wind_dir_degrees  start_date  end_date  start_hour  end_hour
# 0               NaN    20150827  20150827       30960     31380
# 1               NaN    20140728  20140728       79560     80220
# 2             305.0    20140609  20140609       31320     31620
# 3               NaN    20150126  20150126       60900     61620
# 4               NaN    20150829  20150829       54540     54840
#
# [5 rows x 36 columns]

# %%
subscription_type = trip_test['subscription_type'].map(lambda x: 1 if x == 'Subscriber' else 0)
trip_test['subscription_type'] = subscription_type
trip_test.head()
# Out:
#    start_station_id  end_station_id  bike_id  subscription_type  \
# 0                60              71      426                  0
# 1                51              82      454                  1
# 2                70              61      370                  1
# 3                72              65      451                  1
# 4                69              51      603                  1
#
#    distancia_entre_estaciones startDate_weekday endDate_weekday  \
# 0                    1.134631          Saturday        Saturday
# 1                    1.170596         Wednesday       Wednesday
# 2                    0.599521          Thursday        Thursday
# 3                    1.166403          Thursday        Thursday
# 4                    1.012936            Friday          Friday
#
#    startDate_deNoche  endDate_deNoche  max_temperature_f    ...     \
# 0                  0                0                NaN    ...
# 1                  0                0                NaN    ...
# 2                  0                0               66.0    ...
# 3                  0                0                NaN    ...
# 4                  0                0                NaN    ...
#
#    mean_wind_speed_mph  max_gust_speed_mph  precipitation_inches  cloud_cover  \
# 0                  NaN                 NaN                   NaN          NaN
# 1                  NaN                 NaN                   NaN          NaN
# 2                 10.0                23.0                     0          3.0
# 3                  NaN                 NaN                   NaN          NaN
# 4                  NaN                 NaN                   NaN          NaN
#
#    events  wind_dir_degrees  start_date  end_date  start_hour  end_hour
# 0     NaN               NaN    20141018  20141018       41100     43920
# 1     NaN               NaN    20141105  20141105       46800     47340
# 2     NaN             286.0    20150618  20150618       63240     63420
# 3     NaN               NaN    20150820  20150820       25560     26100
# 4     NaN               NaN    20140613  20140613       31560     32220
#
# [5 rows x 35 columns]

# %%
trip_train['events'].value_counts()
# Out:
# Rain                 8640
# Fog                  5415
# Fog-Rain              955
# Rain-Thunderstorm     176
# rain                   38
# Name: events, dtype: int64

# %%
trip_train['precipitation_inches'] = trip_train['precipitation_inches'].map(lambda x: 0.01 if x == 'T' else x)
trip_test['precipitation_inches'] = trip_test['precipitation_inches'].map(lambda x: 0.01 if x == 'T' else x)

# %%
#convertimos las clases de la columna events
events = trip_train['events'].map(lambda x: 0 if ((x == 'rain') or (x == 'Rain')) else 1 if x == 'Fog' else 2 if x == 'Fog-Rain' else 3 if x == 'Rain-Thunderstorm' else 4)
trip_train['events'] = events
trip_train.head()
# Out:
#    duration  start_station_id  end_station_id  bike_id  subscription_type  \
# 0       396                50              60      187                  1
# 1       636                67              46      417                  1
# 2       334                77              62      281                  1
# 3       666                69              55      634                  1
# 4       318                67              39      607                  1
#
#    distancia_entre_estaciones startDate_weekday endDate_weekday  \
# 0                    1.148453          Thursday        Thursday
# 1                    1.794651            Monday          Monday
# 2                    0.569924            Monday          Monday
# 3                    0.788625            Monday          Monday
# 4                    1.084530          Saturday        Saturday
#
#    startDate_deNoche  endDate_deNoche    ...     mean_wind_speed_mph  \
# 0                  0                0    ...                     NaN
# 1                  1                1    ...                     NaN
# 2                  0                0    ...                    10.0
# 3                  0                0    ...                     NaN
# 4                  0                0    ...                     NaN
#
#    max_gust_speed_mph  precipitation_inches  cloud_cover  events  \
# 0                 NaN                   NaN          NaN       4
# 1                 NaN                   NaN          NaN       4
# 2                25.0                     0          1.0       4
# 3                 NaN                   NaN          NaN       4
# 4                 NaN                   NaN          NaN       4
#
#    wind_dir_degrees  start_date  end_date  start_hour  end_hour
# 0               NaN    20150827  20150827       30960     31380
# 1               NaN    20140728  20140728       79560     80220
# 2             305.0    20140609  20140609       31320     31620
# 3               NaN    20150126  20150126       60900     61620
# 4               NaN    20150829  20150829       54540     54840
#
# [5 rows x 36 columns]

# %%
events = trip_test['events'].map(lambda x: 0 if ((x == 'rain') or (x == 'Rain')) else 1 if x == 'Fog' else 2 if x == 'Fog-Rain' else 3 if x == 'Rain-Thunderstorm' else 4)
trip_test['events'] = events
trip_test.head()
# Out:
#    start_station_id  end_station_id  bike_id  subscription_type  \
# 0                60              71      426                  0
# 1                51              82      454                  1
# 2                70              61      370                  1
# 3                72              65      451                  1
# 4                69              51      603                  1
#
#    distancia_entre_estaciones startDate_weekday endDate_weekday  \
# 0                    1.134631          Saturday        Saturday
# 1                    1.170596         Wednesday       Wednesday
# 2                    0.599521          Thursday        Thursday
# 3                    1.166403          Thursday        Thursday
# 4                    1.012936            Friday          Friday
#
#    startDate_deNoche  endDate_deNoche  max_temperature_f    ...     \
# 0                  0                0                NaN    ...
# 1                  0                0                NaN    ...
# 2                  0                0               66.0    ...
# 3                  0                0                NaN    ...
# 4                  0                0                NaN    ...
#
#    mean_wind_speed_mph  max_gust_speed_mph  precipitation_inches  cloud_cover  \
# 0                  NaN                 NaN                   NaN          NaN
# 1                  NaN                 NaN                   NaN          NaN
# 2                 10.0                23.0                     0          3.0
# 3                  NaN                 NaN                   NaN          NaN
# 4                  NaN                 NaN                   NaN          NaN
#
#    events  wind_dir_degrees  start_date  end_date  start_hour  end_hour
# 0       4               NaN    20141018  20141018       41100     43920
# 1       4               NaN    20141105  20141105       46800     47340
# 2       4             286.0    20150618  20150618       63240     63420
# 3       4               NaN    20150820  20150820       25560     26100
# 4       4               NaN    20140613  20140613       31560     32220
#
# [5 rows x 35 columns]

# %%
#convertimos las clases de los dias de semana
startDays = trip_train['startDate_weekday'].map(lambda x: 0 if x == 'Monday' else 1 if x == 'Thursday' 
                                             else 2 if x == 'Wednesday' else 3 if x == 'Tuesday' else 4 if x == 'Friday'
                                            else 5 if x == 'Saturday' else 6)
trip_train['startDate_weekday'] = startDays

endDays = trip_train['endDate_weekday'].map(lambda x: 0 if x == 'Monday' else 1 if x == 'Thursday' 
                                             else 2 if x == 'Wednesday' else 3 if x == 'Tuesday' else 4 if x == 'Friday'
                                            else 5 if x == 'Saturday' else 6)
trip_train['endDate_weekday'] = endDays
trip_train['startDate_weekday'].value_counts()
# Out:
# 3    100410
# 2     98407
# 1     97751
# 0     95118
# 4     89915
# 5     36773
# 6     31587
# Name: startDate_weekday, dtype: int64

# %%
#convertimos las clases de los dias de semana
startDays = trip_test['startDate_weekday'].map(lambda x: 0 if x == 'Monday' else 1 if x == 'Thursday' 
                                             else 2 if x == 'Wednesday' else 3 if x == 'Tuesday' else 4 if x == 'Friday'
                                            else 5 if x == 'Saturday' else 6)
trip_test['startDate_weekday'] = startDays

endDays = trip_test['endDate_weekday'].map(lambda x: 0 if x == 'Monday' else 1 if x == 'Thursday' 
                                             else 2 if x == 'Wednesday' else 3 if x == 'Tuesday' else 4 if x == 'Friday'
                                            else 5 if x == 'Saturday' else 6)
trip_test['endDate_weekday'] = endDays
trip_test['startDate_weekday'].value_counts()
# Out:
# 3    21849
# 2    21794
# 1    21338
# 0    20755
# 4    19446
# 5     8012
# 6     6804
# Name: startDate_weekday, dtype: int64

# %%
trip_train['endDate_weekday'].value_counts()
# Out:
# 3    100425
# 2     98424
# 1     97756
# 0     95166
# 4     89755
# 5     36741
# 6     31694
# Name: endDate_weekday, dtype: int64

# %%
trip_train['events'].value_counts()
# Out:
# 4    534737
# 0      8678
# 1      5415
# 2       955
# 3       176
# Name: events, dtype: int64

# %%
weather.columns
# Out:
# Index(['date', 'max_temperature_f', 'mean_temperature_f', 'min_temperature_f',
#        'max_dew_point_f', 'mean_dew_point_f', 'min_dew_point_f',
#        'max_humidity', 'mean_humidity', 'min_humidity',
#        'max_sea_level_pressure_inches', 'mean_sea_level_pressure_inches',
#        'min_sea_level_pressure_inches', 'max_visibility_miles',
#        'mean_visibility_miles', 'min_visibility_miles', 'max_wind_Speed_mph',
#        'mean_wind_speed_mph', 'max_gust_speed_mph', 'precipitation_inches',
#        'cloud_cover', 'events', 'wind_dir_degrees', 'zip_code'],
#       dtype='object')

# %%
del trip_train['bike_id']
del trip_train['mean_temperature_f']
del trip_train['min_temperature_f']
del trip_train['max_dew_point_f']
del trip_train['min_dew_point_f']
del trip_train['mean_dew_point_f']
del trip_train['mean_humidity']
del trip_train['min_humidity']
del trip_train['max_sea_level_pressure_inches']
del trip_train['min_sea_level_pressure_inches']
del trip_train['mean_sea_level_pressure_inches']
del trip_train['wind_dir_degrees']
del trip_train['mean_visibility_miles']
del trip_train['min_visibility_miles']
del trip_train['max_wind_Speed_mph']
del trip_train['max_humidity']

del trip_test['bike_id']
del trip_test['mean_temperature_f']
del trip_test['min_temperature_f']
del trip_test['max_dew_point_f']
del trip_test['min_dew_point_f']
del trip_test['mean_dew_point_f']
del trip_test['mean_humidity']
del trip_test['min_humidity']
del trip_test['max_sea_level_pressure_inches']
del trip_test['min_sea_level_pressure_inches']
del trip_test['mean_sea_level_pressure_inches']
del trip_test['wind_dir_degrees']
del trip_test['mean_visibility_miles']
del trip_test['min_visibility_miles']
del trip_test['max_wind_Speed_mph']
del trip_test['max_humidity']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# M:\Users\Krion\Anaconda3\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4433)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4279)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13742)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13696)()
#
# KeyError: 'bike_id'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-146-bd7a2f74723e> in <module>()
# ----> 1 del trip_train['bike_id']
#       2 del trip_train['mean_temperature_f']
#       3 del trip_train['min_temperature_f']
#       4 del trip_train['max_dew_point_f']
#       5 del trip_train['min_dew_point_f']
#
# M:\Users\Krion\Anaconda3\lib\site-packages\pandas\core\generic.py in __delitem__(self, key)
#    1640             # there was no match, this call should raise the appropriate
#    1641             # exception:
# -> 1642             self._data.delete(key)
#    1643
#    1644         # delete from the caches
#
# M:\Users\Krion\Anaconda3\lib\site-packages\pandas\core\internals.py in delete(self, item)
#    3600         Delete selected item (items if non-unique) in-place.
#    3601         """
# -> 3602         indexer = self.items.get_loc(item)
#    3603
#    3604         is_deleted = np.zeros(self.shape[0], dtype=np.bool_)
#
# M:\Users\Krion\Anaconda3\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
# -> 2136                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2137
#    2138         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4433)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4279)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13742)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13696)()
#
# KeyError: 'bike_id'

# %%
trip_train['intervalo'] = trip_train['end_hour'] - trip_train['start_hour']
trip_test['intervalo'] = trip_test['end_hour'] - trip_test['start_hour']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# M:\Users\Krion\Anaconda3\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4433)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4279)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13742)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13696)()
#
# KeyError: 'end_hour'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-147-702e4c4d2603> in <module>()
# ----> 1 trip_train['intervalo'] = trip_train['end_hour'] - trip_train['start_hour']
#       2 trip_test['intervalo'] = trip_test['end_hour'] - trip_test['start_hour']
#
# M:\Users\Krion\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# M:\Users\Krion\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# M:\Users\Krion\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1384         res = cache.get(item)
#    1385         if res is None:
# -> 1386             values = self._data.get(item)
#    1387             res = self._box_item_values(item, values)
#    1388             cache[item] = res
#
# M:\Users\Krion\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3541
#    3542             if not isnull(item):
# -> 3543                 loc = self.items.get_loc(item)
#    3544             else:
#    3545                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# M:\Users\Krion\Anaconda3\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
# -> 2136                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2137
#    2138         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4433)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4279)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13742)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas\hashtable.c:13696)()
#
# KeyError: 'end_hour'

# %%
trip_train = trip_train.drop(['start_date',
       'end_date', 'start_hour', 'end_hour'] ,axis = 1)

trip_test = trip_test.drop(['start_date',
       'end_date', 'start_hour', 'end_hour'] ,axis = 1)

# %%
q = trip_train 
test = trip_test
#w = test
q
# Out:
#         duration  start_station_id  end_station_id  subscription_type  \
# 0            396                50              60                  1
# 1            636                67              46                  1
# 2            334                77              62                  1
# 3            666                69              55                  1
# 4            318                67              39                  1
# 5            337                65              70                  1
# 6            394                64              61                  1
# 549951                    0.732210                  3                3
# 549952                    1.010336                  1                1
# 549953                    1.550615                  0                0
# 549954                    0.707748                  0                0
# 549955                    2.458643                  1                1
# 549956                    1.896097                  2                2
# 549957                    2.037939                  5                5
# 549958                    1.116122                  3                3
# 549959                    1.218653                  3                3
# 549960                    1.164889                  1                1
#
#         startDate_deNoche  endDate_deNoche  max_temperature_f  \
# 0                       0                0                NaN
# 1                       1                1                NaN
# 2                       0                0               78.0
# 3                       0                0                NaN
# 4                       0                0                NaN
# 5                       1                1               71.0
# 6                       0                0               77.0
# 7                       0                0               75.0
# 8                       0                0                NaN
# 9                       1                1                NaN
# 10                      0                0                NaN
# 11                      0                0                NaN
# 12                      0                0                NaN
# 13                      0                0               69.0
# 14                      0                0               81.0
# 15                      0                0                NaN
# 16                      0                0               72.0
# 17                      0                0                NaN
# 18                      0                0                NaN
# 19                      0                0                NaN
# 20                      0                0                NaN
# 21                      0                0                NaN
# 22                      0                0                NaN
# 23                      0                0                NaN
# 24                      0                0                NaN
# 25                      0                0                NaN
# 26                      0                0                NaN
# 27                      0                0                NaN
# 28                      1                1                NaN
# 29                      0                0                NaN
# ...                   ...              ...                ...
# 549931                  0                0                NaN
# 549932                  0                0                NaN
# 549933                  0                0                NaN
# 549934                  0                0                NaN
# 549935                  0                0                NaN
# 549936                  0                0               67.0
# 549937                  0                0                NaN
# 549938                  0                0               63.0
# 549939                  0                0                NaN
# 549940                  1                1                NaN
# 549941                  0                0                NaN
# 549942                  1                1               56.0
# 549943                  0                0                NaN
# 549944                  0                0                NaN
# 549945                  0                0                NaN
# 549946                  0                0                NaN
# 549947                  0                0                NaN
# 549948                  1                1                NaN
# 549949                  0                0                NaN
# 549950                  0                0                NaN
# 549951                  0                0                NaN
# 549952                  0                0                NaN
# 549953                  1                1                NaN
# 549954                  1                1                NaN
# 549955                  0                0                NaN
# 549956                  0                0                NaN
# 549957                  0                0               66.0
# 549958                  0                0                NaN
# 549959                  0                0                NaN
# 549960                  0                0                NaN
#
#         max_visibility_miles  mean_wind_speed_mph  max_gust_speed_mph  \
# 0                        NaN                  NaN                 NaN
# 1                        NaN                  NaN                 NaN
# 2                       10.0                 10.0                25.0
# 3                        NaN                  NaN                 NaN
# 4                        NaN                  NaN                 NaN
# 5                       10.0                  6.0                26.0
# 6                       10.0                 10.0                24.0
# 7                       10.0                  5.0                17.0
# 8                        NaN                  NaN                 NaN
# 9                        NaN                  NaN                 NaN
# 10                       NaN                  NaN                 NaN
# 11                       NaN                  NaN                 NaN
# 12                       NaN                  NaN                 NaN
# 13                      10.0                  7.0                29.0
# 14                      10.0                  9.0                25.0
# 15                       NaN                  NaN                 NaN
# 16                      10.0                  9.0                22.0
# 17                       NaN                  NaN                 NaN
# 18                       NaN                  NaN                 NaN
# 19                       NaN                  NaN                 NaN
# 20                       NaN                  NaN                 NaN
# 21                       NaN                  NaN                 NaN
# 22                       NaN                  NaN                 NaN
# 23                       NaN                  NaN                 NaN
# 24                       NaN                  NaN                 NaN
# 25                       NaN                  NaN                 NaN
# 26                       NaN                  NaN                 NaN
# 549815                    0          1.0       4        540
# 549820                    0          1.0       4        600
# 549823                    0          3.0       4        480
# 549827                 0.01          6.0       0        420
# 549828                 0.01          5.0       0        540
# 549829                    0          5.0       4        420
# 549837                    0          1.0       4        600
# 549840                    0          7.0       4       1920
# 549845                    0          2.0       4       1440
# 549847                    0          3.0       4        480
# 549848                 0.91          8.0       0        480
# 549858                    0          5.0       4        360
# 549862                    0          4.0       4        540
# 549886                    0          7.0       1       1020
# 549887                 0.64          8.0       0        480
# 549898                    0          1.0       4        600
# 549903                    0          6.0       1        300
# 549906                    0          4.0       4        720
# 549918                    0          5.0       4        180
# 549921                    0          5.0       4        540
# 549923                 0.01          3.0       1        420
# 549936                    0          6.0       4        240
# 549938                 0.01          4.0       0        180
# 549942                    0          3.0       4        480
# 549957                    0          1.0       4        840
#
# [78274 rows x 17 columns]

# %%
a = q['duration'].mean()
b = q['start_station_id'].mean()
c = q['end_station_id'].mean()
d = q['subscription_type'].mean()
e = q['distancia_entre_estaciones'].mean()
f = q['startDate_weekday'].mean()
g = q['endDate_weekday'].mean()
h = q['startDate_deNoche'].mean()
i = q['endDate_deNoche'].mean()
j = q['max_temperature_f'].mean()
k = q['max_visibility_miles'].mean()
l = q['mean_wind_speed_mph'].mean()
m = q['max_gust_speed_mph'].mean()
#n = q['precipitation_inches'].mean()
o = q['cloud_cover'].mean()
p = q['events'].mean()


#ac = q['mean_temperature_f'].mean()
#ad = q['min_temperature_f'].mean()
#ae = q['max_dew_point_f'].mean()
#af = q['min_dew_point_f'].mean()
#ag = q['mean_dew_point_f'].mean()
#ah = q['mean_humidity'].mean()
#ai = q['min_humidity'].mean()
#aj = q['max_sea_level_pressure_inches'].mean()
#ak = q['min_sea_level_pressure_inches'].mean()
#al = q['mean_sea_level_pressure_inches'].mean()
#am = q['wind_dir_degrees'].mean()
#an = q['mean_visibility_miles'].mean()
#ao = q['min_visibility_miles'].mean()
#ap = q['max_wind_Speed_mph'].mean()
#aq = q['max_humidity'].mean()

# %%
q1 = q.dropna(how='all')
q1 = q1.replace([np.inf, -np.inf], np.nan)
#q1 = q.fillna(0)
q1['duration'] = q['duration'].fillna(a)
q1['start_station_id'] = q['start_station_id'].fillna(b)
q1['end_station_id'] = q['end_station_id'].fillna(c)
q1['subscription_type'] = q['subscription_type'].fillna(d)
q1['distancia_entre_estaciones'] = q['distancia_entre_estaciones'].fillna(e)
q1['startDate_weekday'] = q['startDate_weekday'].fillna(f)
q1['endDate_weekday'] = q['endDate_weekday'].fillna(g)
q1['startDate_deNoche'] = q['startDate_deNoche'].fillna(h)
q1['endDate_deNoche'] = q['endDate_deNoche'].fillna(i)
q1['max_temperature_f'] = q['max_temperature_f'].fillna(j)
q1['max_visibility_miles'] = q['max_visibility_miles'].fillna(k)
q1['mean_wind_speed_mph'] = q['mean_wind_speed_mph'].fillna(l)
q1['max_gust_speed_mph'] = q['max_gust_speed_mph'].fillna(m)
q1['precipitation_inches'] = q['precipitation_inches'].fillna(0)
q1['cloud_cover'] = q['cloud_cover'].fillna(o)
q1['events'] = q['events'].fillna(p)
q2 = q1
#q1 = q1.replace(q1.mean(),np.nan)
#w = q.fillna(0)


#q1['mean_temperature_f'] = q['mean_temperature_f'].fillna(ac)
#q1['min_temperature_f']  = q['min_temperature_f'].fillna(ad)
#q1['max_dew_point_f'] = q['max_dew_point_f'].fillna(ae)
#q1['min_dew_point_f'] = q['min_dew_point_f'].fillna(af)
#q1['mean_dew_point_f'] = q['mean_dew_point_f'].fillna(ag)
#q1['mean_humidity'] = q['mean_humidity'].fillna(ah)
#q1['min_humidity'] = q['min_humidity'].fillna(ai)
#q1['max_sea_level_pressure_inches'] =q['max_sea_level_pressure_inches'].fillna(aj)
#q1['min_sea_level_pressure_inches']  = q['min_sea_level_pressure_inches'].fillna(ak)
#q1['mean_sea_level_pressure_inches'] = q['mean_sea_level_pressure_inches'].fillna(al)
#q1['wind_dir_degrees'] = q['wind_dir_degrees'].fillna(am)
#q1['mean_visibility_miles'] = q['mean_visibility_miles'].fillna(an)
#q1['min_visibility_miles']  = q['min_visibility_miles'].fillna(ao)
#q1['max_wind_Speed_mph'] = q['max_wind_Speed_mph'].fillna(ap)
#q1['max_humidity'] = q['max_humidity'].fillna(aq)

# %%
q = test
a = q['duration'].mean()
b = q['start_station_id'].mean()
c = q['end_station_id'].mean()
d = q['subscription_type'].mean()
e = q['distancia_entre_estaciones'].mean()
f = q['startDate_weekday'].mean()
g = q['endDate_weekday'].mean()
h = q['startDate_deNoche'].mean()
i = q['endDate_deNoche'].mean()
j = q['max_temperature_f'].mean()
k = q['max_visibility_miles'].mean()
l = q['mean_wind_speed_mph'].mean()
m = q['max_gust_speed_mph'].mean()
#n = q['precipitation_inches'].mean()
o = q['cloud_cover'].mean()
p = q['events'].mean()

# %%
q1 = q.dropna(how='all')
q1 = q1.replace([np.inf, -np.inf], np.nan)
#q1 = q.fillna(0)
q1['duration'] = q['duration'].fillna(a)
q1['start_station_id'] = q['start_station_id'].fillna(b)
q1['end_station_id'] = q['end_station_id'].fillna(c)
q1['subscription_type'] = q['subscription_type'].fillna(d)
q1['distancia_entre_estaciones'] = q['distancia_entre_estaciones'].fillna(e)
q1['startDate_weekday'] = q['startDate_weekday'].fillna(f)
q1['endDate_weekday'] = q['endDate_weekday'].fillna(g)
q1['startDate_deNoche'] = q['startDate_deNoche'].fillna(h)
q1['endDate_deNoche'] = q['endDate_deNoche'].fillna(i)
q1['max_temperature_f'] = q['max_temperature_f'].fillna(j)
q1['max_visibility_miles'] = q['max_visibility_miles'].fillna(k)
q1['mean_wind_speed_mph'] = q['mean_wind_speed_mph'].fillna(l)
q1['max_gust_speed_mph'] = q['max_gust_speed_mph'].fillna(m)
q1['precipitation_inches'] = q['precipitation_inches'].fillna(0)
q1['cloud_cover'] = q['cloud_cover'].fillna(o)
q1['events'] = q['events'].fillna(p)

test = q1
q1 = q2

# %%
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler

q5 = q1
dur = q5['end_hour'] - q5['start_hour']
q5['dur'] = dur
q5['is_true'] = np.random.uniform(0,1,len(trip_train)) <= 0.1
pruebaD, pruebaT = q5[q5['is_true']==True], q5[q5['is_true']==False]
del q5['is_true']
del pruebaD['is_true']
del pruebaT['is_true']
pruebaD_x = pruebaD.drop('duration'
             , axis=1)
pruebaD_y = pruebaD['duration']
    
pruebaT_x = pruebaT.drop('duration'
             , axis=1)
pruebaT_y = pruebaT['duration']

pruebaD_x = preprocessing.normalize(pruebaD_x)
#pruebaT_x = preprocessing.normalize(pruebaT_x)
#numpyMatrix = pruebaD_x.as_matrix().astype(float)
#pruebaD_x = preprocessing.scale(pruebaD_x)
#pruebaT_x = preprocessing.scale(pruebaT_x)

scaler = StandardScaler()
scaler.fit(pruebaD_x) 
pruebaD_x= scaler.transform(pruebaD_x)
#pruebaD_y = scaler.transform(pruebaD_y)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from numpy import random
from sklearn.svm import LinearSVR
from sklearn import linear_model
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import make_scorer
import time
#for i in range(50):
print("[INFO] tuning hyperparameters via grid search")
        
params = [
         { 'average' : [False] , 'loss' : ['squared_epsilon_insensitive'],
          'penalty': ['l1', 'l2', 'elasticnet'] ,'learning_rate' : ['invscaling'] , 'eta0' : [1,0.1,0.01,0.0001,0.000000001], 'power_t' : [0.001,0.1,0.45,0.01,0.6],
          'epsilon' : [0.8,0.85,0.1], 'l1_ratio' : [0.4,0.5,0.6,0.8],  'n_iter' : [np.ceil(10**6 / len(pruebaD_x))],
             'alpha' : [1,0.1,0.01,0.001,0.0001,0.0001,0.00001]}  
]
  
#param_dist = {'average' : [True] , 'loss' : ['squared_loss','huber','squared_epsilon_insensitive'],
#              'penalty': ['l1'] ,'learning_rate' : ['optimal', 'invscaling'] , 'eta0' : [ random.uniform(0.0000001, 0.2), random.uniform(0.0000001, 0.2) ,random.uniform(0.0000001, 0.2) ], 'power_t' : [ random.uniform(0.1, 0.6), random.uniform(0.1, 0.6), random.uniform(0.1, 0.6) , random.uniform(0.1, 0.6)],
#             'epsilon' : [random.uniform(0,100), random.uniform(0,100), random.uniform(0,100)], 'l1_ratio' : [random.uniform(0,1),random.uniform(0,1),random.uniform(0,1)], 
#                'alpha' : [random.uniform(0.000001,0.5)]}      
#    
model = linear_model.SGDRegressor()
#grid = RandomizedSearchCV(model, param_distributions=param_dist, n_iter=20)

grid = GridSearchCV(model, params, n_jobs = -1)
start = time.time()
print("[INFO] fitting stage")
grid = grid.fit(pruebaD_x, pruebaD_y)
acc = grid.best_score_

print("[INFO] grid search took {:.2f} seconds".format(time.time() - start))
print("[INFO] grid search accuracy: {:.2f}%".format(acc * 100))
print("[INFO] grid search best parameters: {}".format(grid.best_params_))
 
#prediction = grid.best_estimator_.predict(pruebaT_x)
#score = mean_squared_error(pruebaT_y, prediction)
#print("[INFO] grid search best parameters predictor score: {}".format((1 - abs(score)) * 100))
# Out:
# [INFO] tuning hyperparameters via grid search
# [INFO] fitting stage
# [INFO] grid search took 2052.62 seconds
# [INFO] grid search accuracy: 7.21%
# [INFO] grid search best parameters: {'alpha': 1, 'average': False, 'epsilon': 0.8, 'eta0': 0.0001, 'l1_ratio': 0.8, 'learning_rate': 'invscaling', 'loss': 'squared_epsilon_insensitive', 'n_iter': 19.0, 'penalty': 'elasticnet', 'power_t': 0.01}

# %%
a = abs(grid.best_estimator_.predict(pruebaD_x))
a[0:20]
# Out:
# array([  358.38686369,   415.63085516,   721.09017981,  1160.08804004,
#         4022.26659539,  1291.02542164,    86.54751264,    90.56950698,
#         3991.52408146,   583.78615836,   618.75636049,  5819.21590603,
#          530.47342908,   538.99846963,   217.02910588,  4655.52704509,
#          325.06900221,   431.29681313,  1101.59842594,   890.73148117])

# %%
pruebaD_y[0:20]

# %%
sklearn.metrics.mean_absolute_error(a,pruebaD_y)
# Out:
# 1178.8633393035411

# %%
from sklearn import preprocessing
dur = q1['end_hour'] - q1['start_hour']
q1['dur'] = dur
q5 = q1
q5['is_true'] = np.random.uniform(0,1,len(trip_train)) <= 0.05
pruebaD, pruebaT = q5[q5['is_true']==True], q5[q5['is_true']==False]
del q5['is_true']
del pruebaD['is_true']
del pruebaT['is_true']
pruebaD_x = pruebaD.drop('duration'
             , axis=1)
pruebaD_y = pruebaD['duration']
    
pruebaT_x = pruebaT.drop('duration'
             , axis=1)
pruebaT_y = pruebaT['duration']
pruebaT_y = pruebaT['duration']
pruebaD_x = preprocessing.normalize(pruebaD_x)
#pruebaT_x = preprocessing.normalize(pruebaT_x)
#numpyMatrix = pruebaD_x.as_matrix().astype(float)
#pruebaD_x = preprocessing.scale(numpyMatrix)
#prebaD_x = preprocessing.scale(pruebaD_x)
#pruebaT_x = preprocessing.scale(pruebaT_x)

# %%
del q1['mean_wind_speed_mph']
del q1['max_gust_speed_mph']
del q1['precipitation_inches']
del q1['cloud_cover']

# %%
q5 = q1

q5
# Out:
#         duration  start_station_id  end_station_id  subscription_type  \
# 0            396                50              60                  1
# 1            636                67              46                  1
# 2            334                77              62                  1
# 3            666                69              55                  1
# 4            318                67              39                  1
# 5            337                65              70                  1
# 6            394                64              61                  1
# 7            766                71              70                  1
# 8            531                62              70                  1
# 9            267                76              75                  0
# 10           766                70              67                  1
# 11           416                77              72                  1
# 12          4120                50              51                  0
# 13           525                69              51                  1
# 14           301                61              70                  1
# 15           311                39              76                  0
# 16           528                56              61                  1
# 17          4675                50              50                  0
# 18           203                54              51                  1
# 19           916                55              66                  1
# 20           246                64              54                  0
# 21           431                77              64                  1
# 22           722                63              65                  1
# 23           275                55              45                  1
# 24           560                74              61                  1
# 25           697                33              28                  1
# 26          1595                50              50                  0
# 27           470                61              50                  1
# 28           372                 2               6                  1
# 29           472                73              77                  1
# ...          ...               ...             ...                ...
# 549931      1111                77              50                  0
# 549932       523                64              56                  1
# 549933       906                60              74                  1
# 549934       600                50              76                  1
# 549935       290                82              75                  1
# 549936       255                69              61                  1
# 549937       933                54              48                  0
# 549938       180                67              72                  1
# 549939       478                72              65                  1
# 549940       682                60              47                  1
# 549941       878                12              14                  1
# 549942       523                67              68                  1
# 549943       266                28              27                  1
# 549944       771                55              70                  1
# 549945       370                67              76                  0
# 549946       462                50              61                  1
# 549947       830                77              70                  1
# 549948       976                46              39                  0
# 549949       659                69              39                  1
# 549950       473                77              72                  1
# 549951      1098                55              61                  1
# 549952       394                62              57                  1
# 549953      1474                41              72                  0
# 549954       347                47              73                  1
# 549955       577                67              70                  1
# 549956       900                60              70                  1
# 549957       832                61              60                  1
# 549958       466                69              57                  0
# 549959       656                71              65                  1
# 549960       293                74              60                  1
#
# 549960             10.104086             7.558569           23.438198
#
#        precipitation_inches  cloud_cover  events  intervalo
# 0                         0     3.570244       4        420
# 1                         0     3.570244       4        660
# 2                         0     1.000000       4        300
# 3                         0     3.570244       4        720
# 4                         0     3.570244       4        300
# 5                         0     5.000000       4        360
# 6                         0     4.000000       4        360
# 7                         0     1.000000       4        780
# 8                         0     3.570244       4        540
# 9                         0     3.570244       4        240
# 10                        0     3.570244       4        780
# 11                        0     3.570244       4        420
# 12                        0     3.570244       4       4080
# 13                        0     5.000000       4        480
# 14                        0     0.000000       4        300
# 15                        0     3.570244       4        300
# 16                        0     3.000000       4        540
# 17                        0     3.570244       4       4680
# 18                        0     3.570244       4        180
# 19                        0     3.570244       4        900
# 20                        0     3.570244       4        240
# 21                        0     3.570244       4        420
# 22                        0     3.570244       4        720
# 23                        0     3.570244       4        300
# 24                        0     3.570244       4        540
# 25                        0     3.570244       4        720
# 26                        0     3.570244       4       1620
# 27                        0     3.570244       4        480
# 28                        0     3.570244       4        420
# 29                        0     3.570244       4        480
# ...                     ...          ...     ...        ...
# 549931                    0     3.570244       4       1140
# 549932                    0     3.570244       4        480
# 549933                    0     3.570244       4        900
# 549934                    0     3.570244       4        600
# 549935                    0     3.570244       4        300
# 549936                    0     6.000000       4        240
# 549937                    0     3.570244       4        900
# 549938                 0.01     4.000000       0        180
# 549939                    0     3.570244       4        480
# 549940                    0     3.570244       4        720
# 549941                    0     3.570244       4        900
# 549942                    0     3.000000       4        480
# 549943                    0     3.570244       4        240
# 549944                    0     3.570244       4        780
# 549945                    0     3.570244       4        360
# 549946                    0     3.570244       4        480
# 549947                    0     3.570244       4        780
# 549948                    0     3.570244       4        960
# 549949                    0     3.570244       4        660
# 549950                    0     3.570244       4        420
# 549951                    0     3.570244       4       1080
# 549952                    0     3.570244       4        420
# 549953                    0     3.570244       4       1500
# 549954                    0     3.570244       4        300
# 549955                    0     3.570244       4        600
# 549956                    0     3.570244       4        900
# 549957                    0     1.000000       4        840
# 549958                    0     3.570244       4        420
# 549959                    0     3.570244       4        660
# 549960                    0     3.570244       4        300
#
# [549961 rows x 17 columns]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import LinearSVR
from sklearn.svm import LinearSVC

from sklearn.svm import SVR
from sklearn import linear_model
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import make_scorer
from sklearn import preprocessing
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
import time

num = 1
max_Accuracy = 0
for i in range(num):
    q5 = q1
    train_x = q5.drop('duration', axis = 1)
    train_y = q5['duration']
    train_x = preprocessing.normalize(train_x)
   
    
    scaler = StandardScaler()
    scaler.fit(train_x) 
    train_x= scaler.transform(train_x)
       
    print("[INFO] tuning hyperparameters via grid search")
        
    #params = [
    #     { 'average' : [False] , 'loss' : ['squared_epsilon_insensitive'],
    #      'penalty': ['elasticnet'] ,'learning_rate' : ['invscaling'] , 'eta0' : [0.1,1,10,100,0.0001,0.001,0.00001], 'power_t' : [0.45],
    #      'epsilon' : [0.01,0.4,0.001,0.1,1,10,0.0001,0.00001,0.0000001], 'l1_ratio' : [0.4], 'n_iter' : [15],
    #         'alpha' : [0.0001]}  
    #]
    
    params = [
         { 'C' : [10] , 'epsilon' : [0], 'random_state' : [0], 'loss' : ['squared_epsilon_insensitive' ]}  
    ]
    
    # params = [
    #      { 'C' : [1] , 'gamma' : ['auto']}  
    #  ]
    
    model = LinearSVR(verbose = 2,tol= 0.000001, max_iter = 2000)
    #model = linear_model.SGDRegressor()
    #model = SVR(cache_size = 7000)
    grid = GridSearchCV(model, params, n_jobs = -1, cv = 5)
    start = time.time()
    print("[INFO] fitting stage")

    grid = grid.fit(train_x, train_y)
    acc = grid.best_score_
    
    
    #acc = grid.best_score_
    #accs = grid.score(x1, y1)
    print("[INFO] grid search took {:.2f} seconds".format(time.time() - start))
    # evaluate the best grid searched model on the testing data
    print("[INFO] grid search accuracy: {:.2f}%".format(acc * 100))
    print("[INFO] grid search best parameters: {}".format(grid.best_params_))
    #print (accs)
# Out:
# [INFO] tuning hyperparameters via grid search
# [INFO] fitting stage
# [LibLinear][INFO] grid search took 724.12 seconds
# [INFO] grid search accuracy: 11.09%
# [INFO] grid search best parameters: {'C': 10, 'epsilon': 0, 'loss': 'squared_epsilon_insensitive', 'random_state': 0}
# M:\Users\Krion\Anaconda3\lib\site-packages\sklearn\svm\base.py:920: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
prediction = grid.best_estimator_.predict(train_x)
train_y[0:30]
# Out:
# 0      396
# 1      636
# 2      334
# 3      666
# 4      318
# 5      337
# 6      394
# 7      766
# 8      531
# 9      267
# 10     766
# 11     416
# 12    4120
# 13     525
# 14     301
# 15     311
# 16     528
# 17    4675
# 18     203
# 19     916
# 20     246
# 21     431
# 22     722
# 23     275
# 24     560
# 25     697
# 26    1595
# 27     470
# 28     372
# 29     472
# Name: duration, dtype: int64

# %%
prediction[0:30]
# Out:
# array([  6.06727077e+03,   8.71700869e+03,   3.50341213e+03,
#          9.98094048e+03,   7.19944303e+02,   2.95822204e+03,
#          3.17064759e+03,   9.77597911e+03,   7.78090828e+03,
#         -6.16199702e+02,   8.60734761e+03,   4.07397889e+03,
#          1.46076136e+04,   5.80402161e+03,   4.29424695e+03,
#          2.36300856e+03,   7.47333575e+03,   1.47751172e+04,
#         -4.78832413e+03,   9.78563090e+03,  -1.20125849e+01,
#          5.31998149e+03,   9.36653580e+03,   1.80300490e+03,
#          7.03380783e+03,   9.46264936e+03,   1.35221338e+04,
#          7.32844813e+03,   8.40513051e+03,   6.48772478e+03])

# %%
def grid_scores_to_df(grid_scores):
    rows = list()
    for grid_score in grid_scores:
        for fold, score in enumerate(grid_score.cv_validation_scores):
            row = grid_score.parameters.copy()
            row['fold'] = fold
            row['score'] = score
            rows.append(row)
    df = pd.DataFrame(rows)
    return df

grid.grid_scores_
# Out:
# M:\Users\Krion\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:667: DeprecationWarning: The grid_scores_ attribute was deprecated in version 0.18 in favor of the more elaborate cv_results_ attribute. The grid_scores_ attribute will not be available from 0.20
#   DeprecationWarning)
# [mean: 0.12352, std: 0.06104, params: {'C': 10, 'epsilon': 0, 'loss': 'epsilon_insensitive', 'random_state': 0}]

# %%
grid.best_estimator_.coef_
# Out:
# array([ -1.32122818e+02,  -1.30373950e+02,  -5.57689802e+00,
#         -1.42966719e+01,   5.89734345e+01,  -6.13606254e+01,
#         -1.01631511e+00,   5.81449636e-01,  -2.48314793e+02,
#         -2.01186160e+02,   3.26390211e+00,  -3.57294617e+01,
#          8.82128493e-01,  -5.82968027e+00,  -2.22167117e+00,
#         -1.18047410e+03])
