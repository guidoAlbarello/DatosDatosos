# %%
#link del repositorio en github: https://github.com/guidoAlbarello/DatosDatosos

# %matplotlib inline

import datetime as dt
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('default') # Make the graphs a bit prettier
plt.rcParams['figure.figsize'] = (15, 5)

# %%
#levantamos los csv

station = pd.read_csv('station.csv', low_memory=False)
trip_test = pd.read_csv('trip_test.csv', low_memory=False)
trip_train = pd.read_csv('trip_train.csv', low_memory=False)
weather = pd.read_csv('weather.csv', low_memory=False)

# %%
status = pd.read_csv('status.csv', low_memory=True)

# %%
#vemos un poco los dataframes de cada csv
station.head()
# Out:
#    id                               name        lat        long  dock_count  \
# 0   2  San Jose Diridon Caltrain Station  37.329732 -121.901782          27
# 1   3              San Jose Civic Center  37.330698 -121.888979          15
# 2   4             Santa Clara at Almaden  37.333988 -121.894902          11
# 3   5                   Adobe on Almaden  37.331415 -121.893200          19
# 4   6                   San Pedro Square  37.336721 -121.894074          15
#
#        city installation_date
# 0  San Jose          8/6/2013
# 1  San Jose          8/5/2013
# 2  San Jose          8/6/2013
# 3  San Jose          8/5/2013
# 4  San Jose          8/7/2013

# %%
status.head()
# Out:
#    station_id  bikes_available  docks_available                 time
# 0           2                2               25  2013/08/29 12:06:01
# 1           2                2               25  2013/08/29 12:07:01
# 2           2                2               25  2013/08/29 12:08:01
# 3           2                2               25  2013/08/29 12:09:01
# 4           2                2               25  2013/08/29 12:10:01

# %%
trip_train.head(10)
# Out:
#        id  duration       start_date                       start_station_name  \
# 0  907649       396   8/27/2015 8:36     Harry Bridges Plaza (Ferry Building)
# 1  384043       636  7/28/2014 22:06                           Market at 10th
# 2  316176       334    6/9/2014 8:42                        Market at Sansome
# 3  618874       666  1/26/2015 16:55  San Francisco Caltrain 2 (330 Townsend)
# 4  910977       318  8/29/2015 15:09                           Market at 10th
# 5  522083       337  10/30/2014 7:00                          Townsend at 7th
# 6  880809       394   8/7/2015 17:11                        2nd at South Park
# 7  488938       766  10/8/2014 14:10            Powell at Post (Union Square)
# 8  899522       531   8/21/2015 7:53                            2nd at Folsom
# 9  737380       267   4/23/2015 6:36                            Market at 4th
#
#    start_station_id         end_date  \
# 0                50   8/27/2015 8:43
# 1                67  7/28/2014 22:17
# 2                77    6/9/2014 8:47
# 3                69  1/26/2015 17:07
# 4                67  8/29/2015 15:14
# 5                65  10/30/2014 7:06
# 6                64   8/7/2015 17:17
# 7                71  10/8/2014 14:23
# 8                62   8/21/2015 8:02
# 9                76   4/23/2015 6:40
#
#                                 end_station_name  end_station_id  bike_id  \
# 0                         Embarcadero at Sansome              60      187
# 1                           Washington at Kearny              46      417
# 2                                  2nd at Folsom              62      281
# 3  Temporary Transbay Terminal (Howard at Beale)              55      634
# 4                             Powell Street BART              39      607
# 5       San Francisco Caltrain (Townsend at 4th)              70      370
# 6                                2nd at Townsend              61      443
# 7       San Francisco Caltrain (Townsend at 4th)              70      485
# 8       San Francisco Caltrain (Townsend at 4th)              70      603
# 9            Mechanics Plaza (Market at Battery)              75       86
#
#   subscription_type zip_code
# 0        Subscriber    94602
# 1        Subscriber    94133
# 2        Subscriber    94107
# 3        Subscriber    94602
# 4        Subscriber    94709
# 5        Subscriber    94107
# 6        Subscriber    94107
# 7        Subscriber    94107
# 8        Subscriber    94549
# 9          Customer    21202

# %%
weather.head()
# Out:
#         date  max_temperature_f  mean_temperature_f  min_temperature_f  \
# 0  8/29/2013               74.0                68.0               61.0
# 1  8/30/2013               78.0                69.0               60.0
# 2  8/31/2013               71.0                64.0               57.0
# 3   9/1/2013               74.0                66.0               58.0
# 4   9/2/2013               75.0                69.0               62.0
#
#    max_dew_point_f  mean_dew_point_f  min_dew_point_f  max_humidity  \
# 0             61.0              58.0             56.0          93.0
# 1             61.0              58.0             56.0          90.0
# 2             57.0              56.0             54.0          93.0
# 3             60.0              56.0             53.0          87.0
# 4             61.0              60.0             58.0          93.0
#
#    mean_humidity  min_humidity   ...     mean_visibility_miles  \
# 0           75.0          57.0   ...                      10.0
# 1           70.0          50.0   ...                      10.0
# 2           75.0          57.0   ...                      10.0
# 3           68.0          49.0   ...                      10.0
# 4           77.0          61.0   ...                      10.0
#
#    min_visibility_miles  max_wind_Speed_mph  mean_wind_speed_mph  \
# 0                  10.0                23.0                 11.0
# 1                   7.0                29.0                 13.0
# 2                  10.0                26.0                 15.0
# 3                  10.0                25.0                 13.0
# 4                   6.0                23.0                 12.0
#
#    max_gust_speed_mph  precipitation_inches  cloud_cover  events  \
# 0                28.0                     0          4.0     NaN
# 1                35.0                     0          2.0     NaN
# 2                31.0                     0          4.0     NaN
# 3                29.0                     0          4.0     NaN
# 4                30.0                     0          6.0     NaN
#
#    wind_dir_degrees zip_code
# 0             286.0    94107
# 1             291.0    94107
# 2             284.0    94107
# 3             284.0    94107
# 4             277.0    94107
#
# [5 rows x 24 columns]

# %%
#vemos de que años son los registros   (2013, 2014,2015)  tal vez lo dice en kaggle pero por las dudas

print(trip_train['start_date'].str.contains('2011').value_counts())
print(trip_train['start_date'].str.contains('2012').value_counts())
print(trip_train['start_date'].str.contains('2013').value_counts())
print(trip_train['start_date'].str.contains('2014').value_counts())
print(trip_train['start_date'].str.contains('2015').value_counts())
print(trip_train['start_date'].str.contains('2016').value_counts())
# Out:
# False    549961
# Name: start_date, dtype: int64
# False    549961
# Name: start_date, dtype: int64
# False    467456
# True      82505
# Name: start_date, dtype: int64
# False    282071
# True     267890
# Name: start_date, dtype: int64
# False    350395
# True     199566
# Name: start_date, dtype: int64
# False    549961
# Name: start_date, dtype: int64

# %%
#promedio de duracion de viajes para cada año

sum = 0
count = trip_train[trip_train['start_date'].str.contains('2013')]['duration'].count()
idx =  (trip_train[trip_train['start_date'].str.contains('2013')])['duration'].value_counts().index.tolist()
i = 0
durations = trip_train[trip_train['start_date'].str.contains('2013')]['duration'].value_counts()
for duration in durations:
    sum += idx[i] * duration
    i += 1
promedioAnio2013 = sum / count

sum = 0
count = trip_train[trip_train['start_date'].str.contains('2014')]['duration'].count()
idx =  (trip_train[trip_train['start_date'].str.contains('2014')])['duration'].value_counts().index.tolist()
i = 0
durations = trip_train[trip_train['start_date'].str.contains('2014')]['duration'].value_counts()
for duration in durations:
    sum += idx[i] * duration
    i += 1
promedioAnio2014 = sum / count

sum = 0
count = trip_train[trip_train['start_date'].str.contains('2015')]['duration'].count()
idx =  (trip_train[trip_train['start_date'].str.contains('2015')])['duration'].value_counts().index.tolist()
i = 0
durations = trip_train[trip_train['start_date'].str.contains('2015')]['duration'].value_counts()
for duration in durations:
    sum += idx[i] * duration
    i += 1
promedioAnio2015 = sum / count

print(promedioAnio2013)
print(promedioAnio2014)
print(promedioAnio2015)
# Out:
# 1318.468008
# 1142.30936952
# 989.85579708

# %%
#graficamos el prmedio por año de duracion de viajes 
# %matplotlib notebook
promediosAnios = [promedioAnio2013, promedioAnio2014, promedioAnio2015]
anios = [2013,2014,2015]
plt.bar(anios, promediosAnios, width = 0.4)
plt.suptitle("Duracion de viaje promedio por año")
plt.xlabel("Años")
plt.ylabel("Duracion promedio de viaje (s)")
plt.xticks(anios, ['2013','2014', '2015'])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
#analizamos en que influye el ser costumer o subscriber respecto al uso de bicis o duration de viaje

trip_train['subscription_type'].value_counts()
# Out:
# Subscriber    465377
# Customer       84584
# Name: subscription_type, dtype: int64

# %%
sum = 0
count = trip_train[trip_train['subscription_type'] == 'Subscriber']['duration'].count()
idx =  trip_train[trip_train['subscription_type'] == 'Subscriber']['duration'].value_counts().index.tolist()
i = 0
durations = trip_train[trip_train['subscription_type'] == 'Subscriber']['duration'].value_counts()
for duration in durations:
    sum += idx[i] * duration
    i += 1
promedioSubscriber = sum / count

sum = 0
count = trip_train[trip_train['subscription_type'] == 'Customer']['duration'].count()
idx =  trip_train[trip_train['subscription_type'] == 'Customer']['duration'].value_counts().index.tolist()
i = 0
durations = trip_train[trip_train['subscription_type'] == 'Customer']['duration'].value_counts()
for duration in durations:
    sum += idx[i] * duration
    i += 1
promedioCustomer = sum / count

#tla vez aca alla problema de la ecuacion de moivre 
print(promedioSubscriber)
print(promedioCustomer)
# Out:
# 588.251312377
# 4002.84203868

# %%
#calculamos duracion promedio por dia de semana

#separamos la fecha por / y eliminamos todo lo q hay mas a la derecha del espacio despues del año
fechas = trip_train['start_date'].map(lambda x: (x.split('/')[0], x.split('/')[1], x.split('/')[2].split(' ')[0]))

#convertimos cada tupla de año mes dia a dia de semana ylo guardamos en un nuevo campo 
trip_train['weekday'] = fechas.map(lambda x: dt.date(int(x[2]),int(x[0]),int(x[1])).strftime("%A"))

# %%
#grafico de viajes q se realizan cada dia de semana 
# %matplotlib notebook

weekday_count = trip_train['weekday'].value_counts()
number = [0,1,2,3,4,5,6]
dias = ['Tue', 'Wed', 'Thu', 'Mon', 'Fri', 'Sat', 'Sun']
plt.bar(number, weekday_count)
plt.suptitle("Cantidad de viajes según el día de semana")
plt.xlabel("Día de la semana")
plt.ylabel("Cantidad de viajes")
plt.xticks(number, dias)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="509">

# %%
#duracion por dia de semana


sum = 0
count = trip_train[trip_train['weekday'] == 'Monday']['duration'].count()
idx =  trip_train[trip_train['weekday'] == 'Monday']['duration'].value_counts().index.tolist()
i = 0
durations = trip_train[trip_train['weekday'] == 'Monday']['duration'].value_counts()
for duration in durations:
    sum += idx[i] * duration
    i += 1
promedioLunes = sum / count

sum = 0
count = trip_train[trip_train['weekday'] == 'Tuesday']['duration'].count()
idx =  trip_train[trip_train['weekday'] == 'Tuesday']['duration'].value_counts().index.tolist()
i = 0
durations = trip_train[trip_train['weekday'] == 'Tuesday']['duration'].value_counts()
for duration in durations:
    sum += idx[i] * duration
    i += 1
promedioMartes = sum / count

sum = 0
count = trip_train[trip_train['weekday'] == 'Wednesday']['duration'].count()
idx =  trip_train[trip_train['weekday'] == 'Wednesday']['duration'].value_counts().index.tolist()
i = 0
durations = trip_train[trip_train['weekday'] == 'Wednesday']['duration'].value_counts()
for duration in durations:
    sum += idx[i] * duration
    i += 1
promedioMiercoles = sum / count

sum = 0
count = trip_train[trip_train['weekday'] == 'Thursday']['duration'].count()
idx =  trip_train[trip_train['weekday'] == 'Thursday']['duration'].value_counts().index.tolist()
i = 0
durations = trip_train[trip_train['weekday'] == 'Thursday']['duration'].value_counts()
for duration in durations:
    sum += idx[i] * duration
    i += 1
promedioJueves = sum / count

sum = 0
count = trip_train[trip_train['weekday'] == 'Friday']['duration'].count()
idx =  trip_train[trip_train['weekday'] == 'Friday']['duration'].value_counts().index.tolist()
i = 0
durations = trip_train[trip_train['weekday'] == 'Friday']['duration'].value_counts()
for duration in durations:
    sum += idx[i] * duration
    i += 1
promedioViernes = sum / count

sum = 0
count = trip_train[trip_train['weekday'] == 'Saturday']['duration'].count()
idx =  trip_train[trip_train['weekday'] == 'Saturday']['duration'].value_counts().index.tolist()
i = 0
durations = trip_train[trip_train['weekday'] == 'Saturday']['duration'].value_counts()
for duration in durations:
    sum += idx[i] * duration
    i += 1
promedioSabado = sum / count

sum = 0
count = trip_train[trip_train['weekday'] == 'Sunday']['duration'].count()
idx =  trip_train[trip_train['weekday'] == 'Sunday']['duration'].value_counts().index.tolist()
i = 0
durations = trip_train[trip_train['weekday'] == 'Sunday']['duration'].value_counts()
for duration in durations:
    sum += idx[i] * duration
    i += 1
promedioDomingo = sum / count
                       
print(promedioLunes)
print(promedioMartes)
print(promedioMiercoles)
print(promedioJueves)
print(promedioViernes)
print(promedioSabado)
print(promedioDomingo)             #habria q chequear estos datos al parecer los findes se viaja mas q el dia de semana. 
                                   #aunq tendria sentido pensando que en la semana se usa mucho para trabajar y el finde para pasear
                                   #y el viernes es mas alto porq se junta trabajo y un poquito de paseo
# Out:
# 845.199636241
# 813.614938751
# 823.866086762
# 879.890210842
# 1050.24347439
# 2935.45892367
# 2557.49631177

# %%
#graficamos los promedios de arriba 
# %matplotlib notebook
promediosDias = [promedioLunes, promedioMartes, promedioMiercoles, promedioJueves, promedioViernes, promedioSabado, promedioDomingo]
number = [0,1,2,3,4,5,6]
dias = [ 'Mon', 'Tue', 'Wed', 'Thu','Fri', 'Sat', 'Sun']
plt.bar(number, promediosDias)
plt.suptitle("Duracion de viaje promedio según el día de semana")
plt.xlabel("Día de la semana")
plt.ylabel("Duracion promedio de viajes (s)")
plt.xticks(number, dias)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="605">

# %%
#status[(status['docks_available'] == 0)]['station_id'].value_counts()

# %%
cantidadVecesConCeroBikesDisponibles = [1] * station['id'].size
j = 0
for stationId in status['station_id'].unique():
    statusConId = status[status['station_id'] == stationId]
    cantidadVecesConCeroBikesDisponibles[j] = statusConId[statusConId['bikes_available'] == 0]['station_id'].count()
    j = j + 1

station['cantidad_veces_cero_bikes_disponibles'] = cantidadVecesConCeroBikesDisponibles

cantidadVecesConCeroDocksDisponibles = [1] * station['id'].size
j = 0
for stationId in status['station_id'].unique():
    statusConId = status[status['station_id'] == stationId]
    cantidadVecesConCeroDocksDisponibles[j] = statusConId[statusConId['docks_available'] == 0]['station_id'].count()
    j = j + 1

station['cantidad_veces_cero_docks_disponibles'] = cantidadVecesConCeroDocksDisponibles

# %%
promedioBikesAvailable = [1] * station['id'].size
j = 0
for stationId in status['station_id'].unique():
    sum = 0
    count = status[status['station_id'] == stationId]['bikes_available'].count()
    idx =  status[status['station_id'] == stationId]['bikes_available'].value_counts().index.tolist()
    i = 0
    availability = status[status['station_id'] == stationId]['bikes_available'].value_counts()
    for bikesAvailable in availability:
        sum += idx[i] * bikesAvailable
        i += 1
    promedioBikesAvailable[j] = round(sum/count , 2)
    j = j + 1
station['promedio_bikes_available'] = promedioBikesAvailable


promedioDocksAvailable = [1] * station['id'].size
j = 0
for stationId in status['station_id'].unique():
    sum = 0
    count = status[status['station_id'] == stationId]['docks_available'].count()
    idx =  status[status['station_id'] == stationId]['docks_available'].value_counts().index.tolist()
    i = 0
    availability = status[status['station_id'] == stationId]['docks_available'].value_counts()
    for docksAvailable in availability:
        sum += idx[i] * docksAvailable
        i += 1
    promedioDocksAvailable[j] = round(sum/count , 2)
    j = j + 1
station['promedio_docks_available'] = promedioDocksAvailable

# %%
station.head()
# Out:
#    id                               name        lat        long  dock_count  \
# 0   2  San Jose Diridon Caltrain Station  37.329732 -121.901782          27
# 1   3              San Jose Civic Center  37.330698 -121.888979          15
# 2   4             Santa Clara at Almaden  37.333988 -121.894902          11
# 3   5                   Adobe on Almaden  37.331415 -121.893200          19
# 4   6                   San Pedro Square  37.336721 -121.894074          15
#
#        city installation_date  cantidad_veces_cero_bikes_disponibles  \
# 0  San Jose          8/6/2013                                   1340
# 1  San Jose          8/5/2013                                   1066
# 2  San Jose          8/6/2013                                  10618
# 3  San Jose          8/5/2013                                   1321
# 4  San Jose          8/7/2013                                   3564
#
#    cantidad_veces_cero_docks_disponibles  promedio_bikes_available  \
# 0                                    466                     13.17
# 1                                   4817                      8.46
# 2                                   6614                      5.29
# 3                                      0                      8.11
# 4                                   3633                      7.61
#
#    promedio_docks_available
# 0                     13.76
# 1                      6.53
# 2                      5.69
# 3                     10.87
# 4                      7.38

# %%
#grafico de todas las estaciones con radiosegun el promedio de las bicicletas disponibles

#mejorar los colores, creando una distancia entre cero y uno 

# %matplotlib notebook

plt.scatter(station['lat'], station['long'], s=station['promedio_bikes_available']*5)

plt.suptitle("Estaciones según el promedio de la cantidad de bicicletas disponibles")
plt.xlabel("Latitud")
plt.ylabel("Longitud")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="971">

# %%
#grafico de todas las estaciones del primer conjunto

#suponemos un criterio para poca, media y mucha cantidad de bicis disponibles

# %matplotlib notebook

lat37 = station[station['lat'] < 37.37]

colors = ["" for x in range(lat37['promedio_bikes_available'].size)]
i = 0
for line in lat37['promedio_bikes_available']:
    if(int(line) < 3):
        colors[i] = 'red'
    elif((int(line) > 3) & (int(line) < 8)):
        colors[i] = 'orange'
    else:
        colors[i] = 'green'
    i = i +1
plt.scatter(lat37['lat'], lat37['long'], s=lat37['promedio_bikes_available']*20, c = colors )

plt.suptitle("Estaciones según el promedio de la cantidad de bicicletas disponibles (1er conjunto)")
plt.xlabel("Latitud")
plt.ylabel("Longitud")
plt.show()
#aregar q si son de un radio menor a x , sean de otro color. tres colores distintos. poco, medio y mucha disponibilidad
# Out:
# <img src="data:image/png;base64,..." width="926">

# %%
#grafico de todas las estaciones del segundo conjunto

# %matplotlib notebook

lat36 = station[(station['lat'] > 37.37) & (station['lat'] < 37.75)]
colors = ["" for x in range(lat36['promedio_bikes_available'].size)]
i = 0
for line in lat36['promedio_bikes_available']:
    if(int(line) < 3):
        colors[i] = 'red'
    elif((int(line) > 3) & (int(line) < 8)):
        colors[i] = 'orange'
    else:
        colors[i] = 'green'
    i = i +1

plt.scatter(lat36['lat'], lat36['long'], s=lat36['promedio_bikes_available']*20, c = colors)
plt.suptitle("Estaciones según el promedio de la cantidad de bicicletas disponibles (2do conjunto)")
plt.xlabel("Latitud")
plt.ylabel("Longitud")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="986">

# %%
#grafico de todas las estaciones del tercer conjunto

# %matplotlib notebook

lat75 = station[station['lat'] > 37.75]
colors = ["" for x in range(lat75['promedio_bikes_available'].size)]
i = 0
for line in lat75['promedio_bikes_available']:
    if(int(line) < 3):
        colors[i] = 'red'
    elif((int(line) > 3) & (int(line) < 8)):
        colors[i] = 'orange'
    else:
        colors[i] = 'green'
    i = i +1

plt.scatter(lat75['lat'], lat75['long'], s=lat75['promedio_bikes_available']*20, c = colors)
plt.suptitle("Estaciones según el promedio de la cantidad de bicicletas disponibles (3er conjunto)")
plt.xlabel("Latitud")
plt.ylabel("Longitud")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1005">

# %%
#grafico de todas las estaciones con radio segun el promedio de los docks disponibles

#falta emprolijarlos. agregar labels titulos

# %matplotlib notebook

plt.scatter(station['lat'], station['long'], s=station['promedio_docks_available']*5)
plt.suptitle("Estaciones según el promedio de la cantidad de docks disponibles")
plt.xlabel("Latitud")
plt.ylabel("Longitud")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1024">

# %%
#grafico de todas las estaciones del primer conjunto

# %matplotlib notebook

lat37 = station[station['lat'] < 37.37]
colors = ["" for x in range(lat37['promedio_docks_available'].size)]
i = 0
for line in lat37['promedio_docks_available']:
    if(int(line) < 3):
        colors[i] = 'red'
    elif((int(line) > 3) & (int(line) < 8)):
        colors[i] = 'orange'
    else:
        colors[i] = 'green'
    i = i +1

plt.scatter(lat37['lat'], lat37['long'], s=lat37['promedio_docks_available']*20, c = colors)
plt.suptitle("Estaciones según el promedio de la cantidad de docks disponibles (1er conjunto)")
plt.xlabel("Latitud")
plt.ylabel("Longitud")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="993">

# %%
#grafico de todas las estaciones del segundo conjunto

# %matplotlib notebook

lat36 = station[(station['lat'] > 37.37) & (station['lat'] < 37.75)]
colors = ["" for x in range(lat36['promedio_docks_available'].size)]
i = 0
for line in lat36['promedio_docks_available']:
    if(int(line) < 3):
        colors[i] = 'red'
    elif((int(line) > 3) & (int(line) < 8)):
        colors[i] = 'orange'
    else:
        colors[i] = 'green'
    i = i +1

plt.scatter(lat36['lat'], lat36['long'], s=lat36['promedio_docks_available']*20, c = colors)
plt.suptitle("Estaciones según el promedio de la cantidad de docks disponibles (2do conjunto)")
plt.xlabel("Latitud")
plt.ylabel("Longitud")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="947">

# %%
#grafico de todas las estaciones del tercer conjunto

# %matplotlib notebook

lat75 = station[station['lat'] > 37.75]
colors = ["" for x in range(lat75['promedio_docks_available'].size)]
i = 0
for line in lat75['promedio_docks_available']:
    if(int(line) < 3):
        colors[i] = 'red'
    elif((int(line) > 3) & (int(line) < 8)):
        colors[i] = 'orange'
    else:
        colors[i] = 'green'
    i = i +1

plt.scatter(lat75['lat'], lat75['long'], s=lat75['promedio_docks_available']*20, c = colors)
plt.suptitle("Estaciones según el promedio de la cantidad de docks disponibles (3er conjunto)")
plt.xlabel("Latitud")
plt.ylabel("Longitud")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="985">

# %%
#grafico de todas las estaciones con radio segun cantidad de veces q se quedaron sin bicis
#falta emprolijarlos. agregar labels titulos

# %matplotlib notebook

plt.scatter(station['lat'], station['long'], s=station['cantidad_veces_cero_bikes_disponibles']/200)
plt.suptitle("Estaciones según el tiempo que se quedaron sin bicicletas")
plt.xlabel("Latitud")
plt.ylabel("Longitud")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="917">

# %%
#grafico de todas las estaciones del primer conjunto

# %matplotlib notebook

lat37 = station[station['lat'] < 37.37]
colors = ["" for x in range(lat37['cantidad_veces_cero_bikes_disponibles'].size)]
i = 0
for line in lat37['cantidad_veces_cero_bikes_disponibles']:
    if(int(line)/1000 < 3):
        colors[i] = 'green'
    elif((int(line)/1000 > 3) & (int(line)/1000 < 8)):
        colors[i] = 'orange'
    else:
        colors[i] = 'red'
    i = i +1

plt.scatter(lat37['lat'], lat37['long'], s=lat37['cantidad_veces_cero_bikes_disponibles']/50, c = colors)
plt.suptitle("Estaciones según el tiempo que se quedaron sin bicicletas (1er conjunto)")
plt.xlabel("Latitud")
plt.ylabel("Longitud")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="880">

# %%
#grafico de todas las estaciones del segundo conjunto

# %matplotlib notebook

lat36 = station[(station['lat'] > 37.37) & (station['lat'] < 37.75)]
colors = ["" for x in range(lat36['cantidad_veces_cero_bikes_disponibles'].size)]
i = 0
for line in lat36['cantidad_veces_cero_bikes_disponibles']:
    if(int(line)/1000 < 3):
        colors[i] = 'green'
    elif((int(line)/1000 > 3) & (int(line)/1000 < 8)):
        colors[i] = 'orange'
    else:
        colors[i] = 'red'
    i = i +1
    
plt.scatter(lat36['lat'], lat36['long'], s=lat36['cantidad_veces_cero_bikes_disponibles']/50, c = colors)
plt.suptitle("Estaciones según el tiempo que se quedaron sin bicicletas (2do conjunto)")
plt.xlabel("Latitud")
plt.ylabel("Longitud")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="923">

# %%
# %matplotlib notebook

lat75 = station[station['lat'] > 37.75]
colors = ["" for x in range(lat75['cantidad_veces_cero_bikes_disponibles'].size)]
i = 0
for line in lat75['cantidad_veces_cero_bikes_disponibles']:
    if(int(line)/1000 < 3):
        colors[i] = 'green'
    elif((int(line)/1000 > 3) & (int(line)/1000 < 8)):
        colors[i] = 'orange'
    else:
        colors[i] = 'red'
    i = i +1
    
plt.scatter(lat75['lat'], lat75['long'], s=lat75['cantidad_veces_cero_bikes_disponibles']/50, c = colors)
plt.suptitle("Estaciones según el tiempo que se quedaron sin bicicletas (3er conjunto)")
plt.xlabel("Latitud")
plt.ylabel("Longitud")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="935">

# %%
#grafico de todas las estaciones con radio segun la cantidad de veces que se quedaron sin docks

#falta emprolijarlos. agregar labels titulos

# %matplotlib notebook

plt.scatter(station['lat'], station['long'], s=station['cantidad_veces_cero_docks_disponibles']/200)
plt.suptitle("Estaciones según el tiempo que se quedaron sin docks")
plt.xlabel("Latitud")
plt.ylabel("Longitud")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="948">

# %%
#grafico de todas las estaciones del primer conjunto

# %matplotlib notebook

lat37 = station[station['lat'] < 37.37]
colors = ["" for x in range(lat37['cantidad_veces_cero_docks_disponibles'].size)]
i = 0
for line in lat37['cantidad_veces_cero_docks_disponibles']:
    if(int(line)/1000 < 3):
        colors[i] = 'green'
    elif((int(line)/1000 > 3) & (int(line)/1000 < 8)):
        colors[i] = 'orange'
    else:
        colors[i] = 'red'
    i = i +1

plt.scatter(lat37['lat'], lat37['long'], s=lat37['cantidad_veces_cero_docks_disponibles']/50, c = colors)
plt.suptitle("Estaciones según el tiempo que se quedaron sin docks (1er conjunto)")
plt.xlabel("Latitud")
plt.ylabel("Longitud")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="964">

# %%
#grafico de todas las estaciones del segundo conjunto

# %matplotlib notebook

lat36 = station[(station['lat'] > 37.37) & (station['lat'] < 37.75)]
colors = ["" for x in range(lat36['cantidad_veces_cero_docks_disponibles'].size)]
i = 0
for line in lat36['cantidad_veces_cero_docks_disponibles']:
    if(int(line)/1000 < 3):
        colors[i] = 'green'
    elif((int(line)/1000 > 3) & (int(line)/1000 < 8)):
        colors[i] = 'orange'
    else:
        colors[i] = 'red'
    i = i +1
plt.scatter(lat36['lat'], lat36['long'], s=lat36['cantidad_veces_cero_docks_disponibles']/50, c = colors)
plt.suptitle("Estaciones según el tiempo que se quedaron sin docks (2do conjunto)")
plt.xlabel("Latitud")
plt.ylabel("Longitud")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="937">

# %%
# %matplotlib notebook

lat75 = station[station['lat'] > 37.75]
colors = ["" for x in range(lat75['cantidad_veces_cero_docks_disponibles'].size)]
i = 0
for line in lat75['cantidad_veces_cero_docks_disponibles']:
    if(int(line)/1000 < 3):
        colors[i] = 'green'
    elif((int(line)/1000 > 3) & (int(line)/1000 < 8)):
        colors[i] = 'orange'
    else:
        colors[i] = 'red'
    i = i +1

plt.scatter(lat75['lat'], lat75['long'], s=lat75['cantidad_veces_cero_docks_disponibles']/50, c = colors)
plt.suptitle("Estaciones según el tiempo que se quedaron sin docks (3er conjunto)")
plt.xlabel("Latitud")
plt.ylabel("Longitud")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="956">

# %%
#ver dia y noche como afecta

#separamos la fecha por / y eliminamos todo lo q hay mas a la derecha del espacio despues del año
fechas = trip_train['start_date'].map(lambda x: (x.split('/')[0], x.split('/')[1], x.split('/')[2].split(' ')[0]))

horas = trip_train['start_date'].map(lambda x:x.split('/')[2].split(' ')[1].split(':')[0])
#convertimos cada tupla de año mes dia a dia de semana ylo guardamos en un nuevo campo 

fechas = fechas.map(lambda x: dt.date(int(x[2]),int(x[0]),int(x[1])).strftime("%m"))

i = 0
deNoche = [0] * fechas.size
for line in fechas:
    if(((int(line) < 4) & (int(line) > 0)) | ((int(line) > 9)&(int(line) < 13))):
        if((int(horas[i]) <18) & (int(horas[i]) > 7)):
            deNoche[i] = 0
        else:
            deNoche[i] = 1
    else:
        if((int(horas[i]) <20) & (int(horas[i]) > 6)):
            deNoche[i] = 0
        else:
            deNoche[i] = 1
    i = i + 1 
        
trip_train['deNoche'] = deNoche

# %%
#cantidad viajes de noche y dia
trip_train['deNoche'].value_counts()
# Out:
# 0    451434
# 1     98527
# Name: deNoche, dtype: int64

# %%
#duracion viajes de noche y dia


sum = 0
count = trip_train[trip_train['deNoche'] == 0]['duration'].count()
idx =  trip_train[trip_train['deNoche'] == 0]['duration'].value_counts().index.tolist()
i = 0
durations = trip_train[trip_train['deNoche'] == 0]['duration'].value_counts()
for duration in durations:
    sum += idx[i] * duration
    i += 1
promedioDia = sum / count

sum = 0
count = trip_train[trip_train['deNoche'] == 1]['duration'].count()
idx =  trip_train[trip_train['deNoche'] == 1]['duration'].value_counts().index.tolist()
i = 0
durations = trip_train[trip_train['deNoche'] == 1]['duration'].value_counts()
for duration in durations:
    sum += idx[i] * duration
    i += 1
promedioNoche = sum / count


print (promedioDia)
print (promedioNoche)
# Out:
# 1093.64407643
# 1204.0039989

# %%
#duracion viajes de dia en dias de semana

sum = 0
count = trip_train[(trip_train['weekday'] == 'Monday') & (trip_train['deNoche'] == 0)]['duration'].count()
idx =  trip_train[(trip_train['weekday'] == 'Monday') & (trip_train['deNoche'] == 0)]['duration'].value_counts().index.tolist()
i = 0
durations = trip_train[(trip_train['weekday'] == 'Monday') & (trip_train['deNoche'] == 0)]['duration'].value_counts()
for duration in durations:
    sum += idx[i] * duration
    i += 1
promedioLunesDia = sum / count

sum = 0
count = trip_train[(trip_train['weekday'] == 'Tuesday') & (trip_train['deNoche'] == 0)]['duration'].count()
idx =  trip_train[(trip_train['weekday'] == 'Tuesday') & (trip_train['deNoche'] == 0)]['duration'].value_counts().index.tolist()
i = 0
durations = trip_train[(trip_train['weekday'] == 'Tuesday') & (trip_train['deNoche'] == 0)]['duration'].value_counts()
for duration in durations:
    sum += idx[i] * duration
    i += 1
promedioMartesDia = sum / count

sum = 0
count = trip_train[(trip_train['weekday'] == 'Wednesday') & (trip_train['deNoche'] == 0)]['duration'].count()
idx =  trip_train[(trip_train['weekday'] == 'Wednesday') & (trip_train['deNoche'] == 0)]['duration'].value_counts().index.tolist()
i = 0
durations = trip_train[(trip_train['weekday'] == 'Wednesday') & (trip_train['deNoche'] == 0)]['duration'].value_counts()
for duration in durations:
    sum += idx[i] * duration
    i += 1
promedioMiercolesDia = sum / count

sum = 0
count = trip_train[(trip_train['weekday'] == 'Thursday') & (trip_train['deNoche'] == 0)]['duration'].count()
idx =  trip_train[(trip_train['weekday'] == 'Thursday') & (trip_train['deNoche'] == 0)]['duration'].value_counts().index.tolist()
i = 0
durations = trip_train[(trip_train['weekday'] == 'Thursday') & (trip_train['deNoche'] == 0)]['duration'].value_counts()
for duration in durations:
    sum += idx[i] * duration
    i += 1
promedioJuevesDia = sum / count

sum = 0
count = trip_train[(trip_train['weekday'] == 'Friday') & (trip_train['deNoche'] == 0)]['duration'].count()
idx =  trip_train[(trip_train['weekday'] == 'Friday') & (trip_train['deNoche'] == 0)]['duration'].value_counts().index.tolist()
i = 0
durations = trip_train[(trip_train['weekday'] == 'Friday') & (trip_train['deNoche'] == 0)]['duration'].value_counts()
for duration in durations:
    sum += idx[i] * duration
    i += 1
promedioViernesDia = sum / count

sum = 0
count = trip_train[(trip_train['weekday'] == 'Saturday') & (trip_train['deNoche'] == 0)]['duration'].count()
idx =  trip_train[(trip_train['weekday'] == 'Saturday') & (trip_train['deNoche'] == 0)]['duration'].value_counts().index.tolist()
i = 0
durations = trip_train[(trip_train['weekday'] == 'Saturday') & (trip_train['deNoche'] == 0)]['duration'].value_counts()
for duration in durations:
    sum += idx[i] * duration
    i += 1
promedioSabadoDia = sum / count

sum = 0
count = trip_train[(trip_train['weekday'] == 'Sunday') & (trip_train['deNoche'] == 0)]['duration'].count()
idx =  trip_train[(trip_train['weekday'] == 'Sunday') & (trip_train['deNoche'] == 0)]['duration'].value_counts().index.tolist()
i = 0
durations = trip_train[(trip_train['weekday'] == 'Sunday') & (trip_train['deNoche'] == 0)]['duration'].value_counts()
for duration in durations:
    sum += idx[i] * duration
    i += 1
promedioDomingoDia = sum / count




#duracion viajes de noche en dias de semana

sum = 0
count = trip_train[(trip_train['weekday'] == 'Monday') & (trip_train['deNoche'] == 1)]['duration'].count()
idx =  trip_train[(trip_train['weekday'] == 'Monday') & (trip_train['deNoche'] == 1)]['duration'].value_counts().index.tolist()
i = 0
durations = trip_train[(trip_train['weekday'] == 'Monday') & (trip_train['deNoche'] == 1)]['duration'].value_counts()
for duration in durations:
    sum += idx[i] * duration
    i += 1
promedioLunesNoche = sum / count

sum = 0
count = trip_train[(trip_train['weekday'] == 'Tuesday') & (trip_train['deNoche'] == 1)]['duration'].count()
idx =  trip_train[(trip_train['weekday'] == 'Tuesday') & (trip_train['deNoche'] == 1)]['duration'].value_counts().index.tolist()
i = 0
durations = trip_train[(trip_train['weekday'] == 'Tuesday') & (trip_train['deNoche'] == 1)]['duration'].value_counts()
for duration in durations:
    sum += idx[i] * duration
    i += 1
promedioMartesNoche = sum / count

sum = 0
count = trip_train[(trip_train['weekday'] == 'Wednesday') & (trip_train['deNoche'] == 1)]['duration'].count()
idx =  trip_train[(trip_train['weekday'] == 'Wednesday') & (trip_train['deNoche'] == 1)]['duration'].value_counts().index.tolist()
i = 0
durations = trip_train[(trip_train['weekday'] == 'Wednesday') & (trip_train['deNoche'] == 1)]['duration'].value_counts()
for duration in durations:
    sum += idx[i] * duration
    i += 1
promedioMiercolesNoche = sum / count

sum = 0
count = trip_train[(trip_train['weekday'] == 'Thursday') & (trip_train['deNoche'] == 1)]['duration'].count()
idx =  trip_train[(trip_train['weekday'] == 'Thursday') & (trip_train['deNoche'] == 1)]['duration'].value_counts().index.tolist()
i = 0
durations = trip_train[(trip_train['weekday'] == 'Thursday') & (trip_train['deNoche'] == 1)]['duration'].value_counts()
for duration in durations:
    sum += idx[i] * duration
    i += 1
promedioJuevesNoche = sum / count

sum = 0
count = trip_train[(trip_train['weekday'] == 'Friday') & (trip_train['deNoche'] == 1)]['duration'].count()
idx =  trip_train[(trip_train['weekday'] == 'Friday') & (trip_train['deNoche'] == 1)]['duration'].value_counts().index.tolist()
i = 0
durations = trip_train[(trip_train['weekday'] == 'Friday') & (trip_train['deNoche'] == 1)]['duration'].value_counts()
for duration in durations:
    sum += idx[i] * duration
    i += 1
promedioViernesNoche = sum / count

sum = 0
count = trip_train[(trip_train['weekday'] == 'Saturday') & (trip_train['deNoche'] == 1)]['duration'].count()
idx =  trip_train[(trip_train['weekday'] == 'Saturday') & (trip_train['deNoche'] == 1)]['duration'].value_counts().index.tolist()
i = 0
durations = trip_train[(trip_train['weekday'] == 'Saturday') & (trip_train['deNoche'] == 1)]['duration'].value_counts()
for duration in durations:
    sum += idx[i] * duration
    i += 1
promedioSabadoNoche = sum / count

sum = 0
count = trip_train[(trip_train['weekday'] == 'Sunday') & (trip_train['deNoche'] == 1)]['duration'].count()
idx =  trip_train[(trip_train['weekday'] == 'Sunday') & (trip_train['deNoche'] == 1)]['duration'].value_counts().index.tolist()
i = 0
durations = trip_train[(trip_train['weekday'] == 'Sunday') & (trip_train['deNoche'] == 1)]['duration'].value_counts()
for duration in durations:
    sum += idx[i] * duration
    i += 1
promedioDomingoNoche = sum / count

# %%
# %matplotlib notebook
promediosDias = [promedioLunesDia, promedioMartesDia, promedioMiercolesDia, promedioJuevesDia, promedioViernesDia, promedioSabadoDia, promedioDomingoDia]
promediosNoches = [promedioLunesNoche, promedioMartesNoche, promedioMiercolesNoche, promedioJuevesNoche, promedioViernesNoche, promedioSabadoNoche, promedioDomingoNoche]

number = [0,1,2,3,4,5,6]
dias = [ 'Mon', 'Tue', 'Wed', 'Thu','Fri', 'Sat', 'Sun']
plt.bar(number, promediosNoches, width = 0.4)
plt.bar(number, promediosDias, width = 0.6, align = 'edge')
plt.suptitle("Duración promedio de día y noche según el día de semana")
plt.xlabel("Duración de viaje (s)")
plt.ylabel("Día de la semana")
plt.xticks(number, dias)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="448">

# %%
#analizar segun las estaciones del año



#separamos la fecha por / y eliminamos todo lo q hay mas a la derecha del espacio despues del año
fechas = trip_train['start_date'].map(lambda x: (x.split('/')[0], x.split('/')[1], x.split('/')[2].split(' ')[0]))

fechas = fechas.map(lambda x: dt.date(int(x[2]),int(x[0]),int(x[1])).strftime("%m%d"))

i = 0
estacion = [0] * fechas.size
for line in fechas:
    if((int(line) < 621) & (int(line) >= 321)):
        estacion[i] = 0
    elif((int(line) < 921) & (int(line) >= 621)):
        estacion[i] = 1
    elif((int(line) < 1221) & (int(line) >= 921)):
        estacion[i] = 2
    else:
        estacion[i] = 3
    i = i + 1 
        
trip_train['estacion'] = estacion

# %%
sum = 0
count = trip_train[trip_train['estacion'] == 0]['duration'].count()
idx =  trip_train[trip_train['estacion'] == 0]['duration'].value_counts().index.tolist()
i = 0
durations = trip_train[trip_train['estacion'] == 0]['duration'].value_counts()
for duration in durations:
    sum += idx[i] * duration
    i += 1
promedioSpring = sum / count

sum = 0
count = trip_train[trip_train['estacion'] == 1]['duration'].count()
idx =  trip_train[trip_train['estacion'] == 1]['duration'].value_counts().index.tolist()
i = 0
durations = trip_train[trip_train['estacion'] == 1]['duration'].value_counts()
for duration in durations:
    sum += idx[i] * duration
    i += 1
promedioSummer = sum / count

sum = 0
count = trip_train[trip_train['estacion'] == 2]['duration'].count()
idx =  trip_train[trip_train['estacion'] == 2]['duration'].value_counts().index.tolist()
i = 0
durations = trip_train[trip_train['estacion'] == 2]['duration'].value_counts()
for duration in durations:
    sum += idx[i] * duration
    i += 1
promedioAutumn = sum / count

sum = 0
count = trip_train[trip_train['estacion'] == 3]['duration'].count()
idx =  trip_train[trip_train['estacion'] == 3]['duration'].value_counts().index.tolist()
i = 0
durations = trip_train[trip_train['estacion'] == 3]['duration'].value_counts()
for duration in durations:
    sum += idx[i] * duration
    i += 1
promedioWinter = sum / count

# %%
#cantidad viajes 

print(trip_train[trip_train['estacion'] == 0]['duration'].count())
print(trip_train[trip_train['estacion'] == 1]['duration'].count())
print(trip_train[trip_train['estacion'] == 2]['duration'].count())
print(trip_train[trip_train['estacion'] == 3]['duration'].count())
# Out:
# 144954
# 153298
# 132886
# 118823

# %%
# %matplotlib notebook

promediosEstaciones = [promedioSpring, promedioSummer, promedioAutumn, promedioWinter]

number = [0,1,2,3]
estacionesDelAnio = [ 'Spr', 'Sum', 'Aut', 'Win']
plt.bar(number, promediosEstaciones, width = 0.2)
plt.suptitle("Duración de viajes según la estación del año")
plt.xlabel("Duración de viaje (s)")
plt.ylabel("Estación del año")
plt.xticks(number, estacionesDelAnio)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="513">

# %%
#averiguamos la cantidad de alquiler de bicis por estacion
alquiler_de_bicis_por_estacion = pd.DataFrame({'alquiler_de_bicis_por_estacion' : trip_train['start_station_name'].value_counts()})
alquiler_de_bicis_por_estacion
# Out:
#                                                alquiler_de_bicis_por_estacion
# San Francisco Caltrain (Townsend at 4th)                                40237
# San Francisco Caltrain 2 (330 Townsend)                                 27666
# Harry Bridges Plaza (Ferry Building)                                    26947
# Embarcadero at Sansome                                                  22759
# Temporary Transbay Terminal (Howard at Beale)                           21478
# 2nd at Townsend                                                         21210
# Steuart at Market                                                       20335
# Market at Sansome                                                       19762
# Townsend at 7th                                                         19451
# Market at 10th                                                          16603
# Market at 4th                                                           16552
# 2nd at South Park                                                       15197
# Powell Street BART                                                      15146
# Grant Avenue at Columbus Avenue                                         13427
# 2nd at Folsom                                                           13080
# Beale at Market                                                         12953
# Embarcadero at Bryant                                                   12257
# Civic Center BART (7th at Market)                                       11670
# Embarcadero at Folsom                                                   11581
# 5th at Howard                                                           11145
# Howard at 2nd                                                           10792
# South Van Ness at Market                                                10618
# Powell at Post (Union Square)                                           10266
# Mechanics Plaza (Market at Battery)                                     10026
# Spear at Folsom                                                          9808
# Commercial at Montgomery                                                 9778
# Yerba Buena Center of the Arts (3rd @ Howard)                            9204
# Embarcadero at Vallejo                                                   8647
# Broadway St at Battery St                                                8375
# Clay at Battery                                                          8262
# ...                                                                       ...
# Castro Street and El Camino Real                                         1701
# MLK Library                                                              1663
# San Antonio Caltrain Station                                             1641
# Japantown                                                                1556
# San Antonio Shopping Center                                              1481
# Ryland Park                                                              1446
# San Salvador at 1st                                                      1383
# Evelyn Park and Ride                                                     1371
# St James Park                                                            1363
# San Jose Civic Center                                                    1319
# Redwood City Caltrain Station                                            1268
# University and Emerson                                                   1230
# SJSU - San Salvador at 9th                                               1205
# Washington at Kearney                                                    1199
# Arena Green / SAP Center                                                 1192
# Cowper at University                                                     1156
# Adobe on Almaden                                                         1033
# SJSU 4th at San Carlos                                                    953
# Rengstorff Avenue / California Street                                     936
# California Ave Caltrain Station                                           833
# Santa Clara County Civic Center                                           699
# Park at Olive                                                             624
# Stanford in Redwood City                                                  352
# Mezes Park                                                                279
# Redwood City Medical Center                                               264
# San Mateo County Center                                                   228
# Franklin at Maple                                                         177
# Redwood City Public Library                                               173
# Broadway at Main                                                           55
# San Jose Government Center                                                 18
#
# [74 rows x 1 columns]

# %%
#graficamos
alquiler_de_bicis_por_estacion.plot(kind='bar')
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
#viajes entre estaciones
viajes_entre_estaciones = trip_train[['start_station_name','end_station_name','duration']]
viajes_entre_estaciones
# Out:
#                                    start_station_name  \
# 0                Harry Bridges Plaza (Ferry Building)
# 1                                      Market at 10th
# 2                                   Market at Sansome
# 3             San Francisco Caltrain 2 (330 Townsend)
# 4                                      Market at 10th
# 5                                     Townsend at 7th
# 6                                   2nd at South Park
# 7                       Powell at Post (Union Square)
# 8                                       2nd at Folsom
# 9                                       Market at 4th
# 10           San Francisco Caltrain (Townsend at 4th)
# 11                                  Market at Sansome
# 12               Harry Bridges Plaza (Ferry Building)
# 13            San Francisco Caltrain 2 (330 Townsend)
# 14                                    2nd at Townsend
# 15                                 Powell Street BART
# 16                                    Beale at Market
# 17               Harry Bridges Plaza (Ferry Building)
# 18                              Embarcadero at Bryant
# 19      Temporary Transbay Terminal (Howard at Beale)
# 20                                  2nd at South Park
# 21                                  Market at Sansome
# 22                                      Howard at 2nd
# 23      Temporary Transbay Terminal (Howard at Beale)
# 24                                  Steuart at Market
# 25              Rengstorff Avenue / California Street
# 26               Harry Bridges Plaza (Ferry Building)
# 27                                    2nd at Townsend
# 28                  San Jose Diridon Caltrain Station
# 29                    Grant Avenue at Columbus Avenue
# ...                                               ...
# 549931                              Market at Sansome
# 549932                              2nd at South Park
# 549933                         Embarcadero at Sansome
# 549934           Harry Bridges Plaza (Ferry Building)
# 549935                      Broadway St at Battery St
# 549936        San Francisco Caltrain 2 (330 Townsend)
# 549937                          Embarcadero at Bryant
# 549938                                 Market at 10th
# 549939              Civic Center BART (7th at Market)
# 549940                         Embarcadero at Sansome
# 549941                         SJSU 4th at San Carlos
# 549942                                 Market at 10th
# 549943                 Mountain View Caltrain Station
# 549944  Temporary Transbay Terminal (Howard at Beale)
# 549945                                 Market at 10th
# 549946           Harry Bridges Plaza (Ferry Building)
# 549947                              Market at Sansome
# 549948                          Washington at Kearney
# 549949        San Francisco Caltrain 2 (330 Townsend)
# 549950                              Market at Sansome
# 549951  Temporary Transbay Terminal (Howard at Beale)
# 549952                                  2nd at Folsom
# 549953                                Clay at Battery
# 549954                                 Post at Kearny
# 549955                                 Market at 10th
# 549956                         Embarcadero at Sansome
# 549957                                2nd at Townsend
# 549958        San Francisco Caltrain 2 (330 Townsend)
# 549959                  Powell at Post (Union Square)
# 549960                              Steuart at Market
#
#                                      end_station_name  duration
# 0                              Embarcadero at Sansome       396
# 1                                Washington at Kearny       636
# 2                                       2nd at Folsom       334
# 3       Temporary Transbay Terminal (Howard at Beale)       666
# 4                                  Powell Street BART       318
# 5            San Francisco Caltrain (Townsend at 4th)       337
# 6                                     2nd at Townsend       394
# 7            San Francisco Caltrain (Townsend at 4th)       766
# 8            San Francisco Caltrain (Townsend at 4th)       531
# 9                 Mechanics Plaza (Market at Battery)       267
# 10                                     Market at 10th       766
# 11                  Civic Center BART (7th at Market)       416
# 12                              Embarcadero at Folsom      4120
# 13                              Embarcadero at Folsom       525
# 14           San Francisco Caltrain (Townsend at 4th)       301
# 15                                      Market at 4th       311
# 16                                    2nd at Townsend       528
# 17               Harry Bridges Plaza (Ferry Building)      4675
# 18                              Embarcadero at Folsom       203
# 19                           South Van Ness at Market       916
# 20                              Embarcadero at Bryant       246
# 21                                  2nd at South Park       431
# 22                                    Townsend at 7th       722
# 23                           Commercial at Montgomery       275
# 24                                    2nd at Townsend       560
# 25                     Mountain View Caltrain Station       697
# 26               Harry Bridges Plaza (Ferry Building)      1595
# 27               Harry Bridges Plaza (Ferry Building)       470
# 28                                   San Pedro Square       372
# 29                                  Market at Sansome       472
# ...                                               ...       ...
# 549931           Harry Bridges Plaza (Ferry Building)      1111
# 549932                                Beale at Market       523
# 549933                              Steuart at Market       906
# 549934                                  Market at 4th       600
# 549935            Mechanics Plaza (Market at Battery)       290
# 549936                                2nd at Townsend       255
# 549937                         Embarcadero at Vallejo       933
# 549938              Civic Center BART (7th at Market)       180
# 549939                                Townsend at 7th       478
# 549940                                 Post at Kearny       682
# 549941                       Arena Green / SAP Center       878
# 549942  Yerba Buena Center of the Arts (3rd @ Howard)       523
# 549943                        Mountain View City Hall       266
# 549944       San Francisco Caltrain (Townsend at 4th)       771
# 549945                                  Market at 4th       370
# 549946                                2nd at Townsend       462
# 549947       San Francisco Caltrain (Townsend at 4th)       830
# 549948                             Powell Street BART       976
# 549949                             Powell Street BART       659
# 549950              Civic Center BART (7th at Market)       473
# 549951                                2nd at Townsend      1098
# 549952                                  5th at Howard       394
# 549953              Civic Center BART (7th at Market)      1474
# 549954                Grant Avenue at Columbus Avenue       347
# 549955       San Francisco Caltrain (Townsend at 4th)       577
# 549956       San Francisco Caltrain (Townsend at 4th)       900
# 549957                         Embarcadero at Sansome       832
# 549958                                  5th at Howard       466
# 549959                                Townsend at 7th       656
# 549960                         Embarcadero at Sansome       293
#
# [549961 rows x 3 columns]

# %%
#tiempo total de los viajes realziados entre las estaciones a,b
duracion_de_viaje_entre_estaciones = viajes_entre_estaciones.groupby(['start_station_name', 'end_station_name']).sum().sort_values(by = 'duration',ascending= False)
duracion_de_viaje_entre_estaciones
# Out:
#                                                                                         duration
# start_station_name                       end_station_name
# South Van Ness at Market                 2nd at Folsom                                  17348497
# Harry Bridges Plaza (Ferry Building)     Harry Bridges Plaza (Ferry Building)            8957008
# Embarcadero at Sansome                   Embarcadero at Sansome                          7612985
# University and Emerson                   University and Emerson                          7432084
# Harry Bridges Plaza (Ferry Building)     Embarcadero at Sansome                          6354034
# Powell at Post (Union Square)            Powell at Post (Union Square)                   5121601
# Market at 4th                            Market at 4th                                   4797817
# Powell Street BART                       Powell Street BART                              4754049
# San Jose Civic Center                    San Jose Civic Center                           3651827
# Market at 10th                           Market at 10th                                  3570319
# Steuart at Market                        Steuart at Market                               3377152
# Mountain View Caltrain Station           Mountain View Caltrain Station                  3358892
# Civic Center BART (7th at Market)        Civic Center BART (7th at Market)               3119911
# San Francisco Caltrain (Townsend at 4th) San Francisco Caltrain (Townsend at 4th)        2954599
# Grant Avenue at Columbus Avenue          Grant Avenue at Columbus Avenue                 2789669
# Embarcadero at Vallejo                   Embarcadero at Vallejo                          2499678
# San Francisco Caltrain (Townsend at 4th) Harry Bridges Plaza (Ferry Building)            2494593
# Embarcadero at Folsom                    San Francisco Caltrain (Townsend at 4th)        2384609
# Embarcadero at Sansome                   Harry Bridges Plaza (Ferry Building)            2374188
# 2nd at Townsend                          Harry Bridges Plaza (Ferry Building)            2374065
# Harry Bridges Plaza (Ferry Building)     2nd at Townsend                                 2371286
# Embarcadero at Bryant                    Embarcadero at Bryant                           2367831
# Palo Alto Caltrain Station               Palo Alto Caltrain Station                      2345878
# Rengstorff Avenue / California Street    Rengstorff Avenue / California Street           2345537
# Market at Sansome                        Yerba Buena Center of the Arts (3rd @ Howard)   2328944
# Steuart at Market                        Embarcadero at Sansome                          2318295
# 5th at Howard                            5th at Howard                                   2265533
# Harry Bridges Plaza (Ferry Building)     San Francisco Caltrain (Townsend at 4th)        2219686
# San Antonio Caltrain Station             San Antonio Caltrain Station                    2169308
# Steuart at Market                        San Francisco Caltrain (Townsend at 4th)        2166265
# ...                                                                                          ...
# Redwood City Medical Center              Franklin at Maple                                  2517
# Cowper at University                     Franklin at Maple                                  2468
# Redwood City Caltrain Station            California Ave Caltrain Station                    2457
# Broadway at Main                         Mezes Park                                         2165
# Cowper at University                     Stanford in Redwood City                           2106
# San Pedro Square                         San Jose Government Center                         2098
# Adobe on Almaden                         Ryland Park                                        2048
# Redwood City Public Library              Palo Alto Caltrain Station                         1983
# University and Emerson                   San Mateo County Center                            1902
# San Jose Government Center               San Pedro Square                                   1865
# San Mateo County Center                  Park at Olive                                      1860
# Stanford in Redwood City                 San Mateo County Center                            1775
# San Jose Government Center               St James Park                                      1652
#                                          Arena Green / SAP Center                           1492
# Redwood City Public Library              Cowper at University                               1463
# Broadway at Main                         Franklin at Maple                                  1413
# SJSU - San Salvador at 9th               San Jose Government Center                         1388
# MLK Library                              San Jose Government Center                         1350
# San Jose Government Center               Paseo de San Antonio                               1342
# Paseo de San Antonio                     San Jose Government Center                         1297
# SJSU 4th at San Carlos                   San Jose Government Center                         1007
# Broadway at Main                         Redwood City Public Library                         929
# San Jose Government Center               Adobe on Almaden                                    915
# Santa Clara County Civic Center          San Salvador at 1st                                 912
# Post at Kearney                          Broadway St at Battery St                           859
# Redwood City Public Library              Redwood City Medical Center                         754
# Broadway St at Battery St                Washington at Kearney                               556
#                                          Post at Kearney                                     488
# Mezes Park                               Broadway at Main                                    485
# Redwood City Caltrain Station            Civic Center BART (7th at Market)                   236
#
# [1907 rows x 1 columns]

# %%
estacion_como_inicio = pd.DataFrame({'cantidad_de_veces_como_inicio' : trip_train['start_station_name'].value_counts()}).reset_index().rename(columns={'index': 'estacion'})
estacion_como_inicio
# Out:
#                                          estacion  \
# 0        San Francisco Caltrain (Townsend at 4th)
# 1         San Francisco Caltrain 2 (330 Townsend)
# 2            Harry Bridges Plaza (Ferry Building)
# 3                          Embarcadero at Sansome
# 4   Temporary Transbay Terminal (Howard at Beale)
# 5                                 2nd at Townsend
# 6                               Steuart at Market
# 7                               Market at Sansome
# 8                                 Townsend at 7th
# 9                                  Market at 10th
# 10                                  Market at 4th
# 11                              2nd at South Park
# 12                             Powell Street BART
# 13                Grant Avenue at Columbus Avenue
# 14                                  2nd at Folsom
# 15                                Beale at Market
# 16                          Embarcadero at Bryant
# 17              Civic Center BART (7th at Market)
# 18                          Embarcadero at Folsom
# 19                                  5th at Howard
# 20                                  Howard at 2nd
# 21                       South Van Ness at Market
# 22                  Powell at Post (Union Square)
# 23            Mechanics Plaza (Market at Battery)
# 24                                Spear at Folsom
# 25                       Commercial at Montgomery
# 26  Yerba Buena Center of the Arts (3rd @ Howard)
# 27                         Embarcadero at Vallejo
# 28                      Broadway St at Battery St
# 29                                Clay at Battery
# ..                                            ...
# 44               Castro Street and El Camino Real
# 45                                    MLK Library
# 46                   San Antonio Caltrain Station
# 47                                      Japantown
# 48                    San Antonio Shopping Center
# 49                                    Ryland Park
# 50                            San Salvador at 1st
# 51                           Evelyn Park and Ride
# 52                                  St James Park
# 53                          San Jose Civic Center
# 54                  Redwood City Caltrain Station
# 55                         University and Emerson
# 56                     SJSU - San Salvador at 9th
# 57                          Washington at Kearney
# 58                       Arena Green / SAP Center
# 59                           Cowper at University
# 60                               Adobe on Almaden
# 61                         SJSU 4th at San Carlos
# 62          Rengstorff Avenue / California Street
# 63                California Ave Caltrain Station
# 64                Santa Clara County Civic Center
# 65                                  Park at Olive
# 66                       Stanford in Redwood City
# 67                                     Mezes Park
# 68                    Redwood City Medical Center
# 69                        San Mateo County Center
# 70                              Franklin at Maple
# 71                    Redwood City Public Library
# 72                               Broadway at Main
# 73                     San Jose Government Center
#
#     cantidad_de_veces_como_inicio
# 0                           40237
# 1                           27666
# 2                           26947
# 3                           22759
# 4                           21478
# 5                           21210
# 6                           20335
# 7                           19762
# 8                           19451
# 9                           16603
# 10                          16552
# 11                          15197
# 12                          15146
# 13                          13427
# 14                          13080
# 15                          12953
# 16                          12257
# 17                          11670
# 18                          11581
# 19                          11145
# 20                          10792
# 21                          10618
# 22                          10266
# 23                          10026
# 24                           9808
# 25                           9778
# 26                           9204
# 27                           8647
# 28                           8375
# 29                           8262
# ..                            ...
# 44                           1701
# 45                           1663
# 46                           1641
# 47                           1556
# 48                           1481
# 49                           1446
# 50                           1383
# 51                           1371
# 52                           1363
# 53                           1319
# 54                           1268
# 55                           1230
# 56                           1205
# 57                           1199
# 58                           1192
# 59                           1156
# 60                           1033
# 61                            953
# 62                            936
# 63                            833
# 64                            699
# 65                            624
# 66                            352
# 67                            279
# 68                            264
# 69                            228
# 70                            177
# 71                            173
# 72                             55
# 73                             18
#
# [74 rows x 2 columns]

# %%
estacion_como_final = pd.DataFrame({'cantidad_de_veces_como_final' : trip_train['end_station_name'].value_counts()}).reset_index().rename(columns={'index': 'estacion'})
estacion_como_final
# Out:
#                                          estacion  \
# 0        San Francisco Caltrain (Townsend at 4th)
# 1         San Francisco Caltrain 2 (330 Townsend)
# 2            Harry Bridges Plaza (Ferry Building)
# 3                          Embarcadero at Sansome
# 4                                 2nd at Townsend
# 5                               Market at Sansome
# 6                                 Townsend at 7th
# 7                               Steuart at Market
# 8   Temporary Transbay Terminal (Howard at Beale)
# 9                                   Market at 4th
# 10                             Powell Street BART
# 11                                 Market at 10th
# 12                              2nd at South Park
# 13                                  5th at Howard
# 14              Civic Center BART (7th at Market)
# 15                                  Howard at 2nd
# 16                          Embarcadero at Folsom
# 17                          Embarcadero at Bryant
# 18                         Embarcadero at Vallejo
# 19                                Beale at Market
# 20  Yerba Buena Center of the Arts (3rd @ Howard)
# 21            Mechanics Plaza (Market at Battery)
# 22                                Spear at Folsom
# 23                       Commercial at Montgomery
# 24                       South Van Ness at Market
# 25                               Davis at Jackson
# 26                                Clay at Battery
# 27                                  2nd at Folsom
# 28              San Jose Diridon Caltrain Station
# 29                      Broadway St at Battery St
# ..                                            ...
# 44                   San Antonio Caltrain Station
# 45                         University and Emerson
# 46                    San Antonio Shopping Center
# 47               Castro Street and El Camino Real
# 48                     Palo Alto Caltrain Station
# 49                          San Jose Civic Center
# 50                          Washington at Kearney
# 51                            San Salvador at 1st
# 52                             San Jose City Hall
# 53                     SJSU - San Salvador at 9th
# 54                                  St James Park
# 55                                    Ryland Park
# 56                         SJSU 4th at San Carlos
# 57                           Evelyn Park and Ride
# 58                       Arena Green / SAP Center
# 59                  Redwood City Caltrain Station
# 60                           Cowper at University
# 61                               Adobe on Almaden
# 62                California Ave Caltrain Station
# 63          Rengstorff Avenue / California Street
# 64                Santa Clara County Civic Center
# 65                                  Park at Olive
# 66                       Stanford in Redwood City
# 67                    Redwood City Medical Center
# 68                        San Mateo County Center
# 69                                     Mezes Park
# 70                    Redwood City Public Library
# 71                              Franklin at Maple
# 72                               Broadway at Main
# 73                     San Jose Government Center
#
#     cantidad_de_veces_como_final
# 0                          51842
# 1                          28709
# 2                          27348
# 3                          25229
# 4                          23411
# 5                          23109
# 6                          21989
# 7                          20530
# 8                          18978
# 9                          16355
# 10                         16274
# 11                         14647
# 12                         13727
# 13                         12247
# 14                         11771
# 15                         11555
# 16                         11114
# 17                         10787
# 18                         10160
# 19                          9975
# 20                          9953
# 21                          9836
# 22                          9474
# 23                          9308
# 24                          9192
# 25                          8509
# 26                          8124
# 27                          7977
# 28                          7690
# 29                          7651
# ..                           ...
# 44                          1695
# 45                          1503
# 46                          1499
# 47                          1490
# 48                          1489
# 49                          1467
# 50                          1458
# 51                          1407
# 52                          1332
# 53                          1219
# 54                          1199
# 55                          1195
# 56                          1190
# 57                          1130
# 58                          1121
# 59                          1015
# 60                          1005
# 61                           974
# 62                           928
# 63                           914
# 64                           685
# 65                           661
# 66                           375
# 67                           373
# 68                           282
# 69                           228
# 70                           218
# 71                           211
# 72                            63
# 73                            19
#
# [74 rows x 2 columns]

# %%
usos_de_estacion = pd.merge(estacion_como_inicio, estacion_como_final, on='estacion')
usos_de_estacion.plot(kind="area", stacked=False)
# Out:
# <img src="data:image/png;base64,..." width="886">

# %%
usos_de_estacion
# Out:
#                                          estacion  \
# 0        San Francisco Caltrain (Townsend at 4th)
# 1         San Francisco Caltrain 2 (330 Townsend)
# 2            Harry Bridges Plaza (Ferry Building)
# 3                          Embarcadero at Sansome
# 4   Temporary Transbay Terminal (Howard at Beale)
# 5                                 2nd at Townsend
# 6                               Steuart at Market
# 7                               Market at Sansome
# 8                                 Townsend at 7th
# 9                                  Market at 10th
# 10                                  Market at 4th
# 11                              2nd at South Park
# 12                             Powell Street BART
# 13                Grant Avenue at Columbus Avenue
# 14                                  2nd at Folsom
# 15                                Beale at Market
# 16                          Embarcadero at Bryant
# 17              Civic Center BART (7th at Market)
# 18                          Embarcadero at Folsom
# 19                                  5th at Howard
# 20                                  Howard at 2nd
# 21                       South Van Ness at Market
# 22                  Powell at Post (Union Square)
# 23            Mechanics Plaza (Market at Battery)
# 24                                Spear at Folsom
# 25                       Commercial at Montgomery
# 26  Yerba Buena Center of the Arts (3rd @ Howard)
# 27                         Embarcadero at Vallejo
# 28                      Broadway St at Battery St
# 29                                Clay at Battery
# ..                                            ...
# 44               Castro Street and El Camino Real
# 45                                    MLK Library
# 46                   San Antonio Caltrain Station
# 47                                      Japantown
# 48                    San Antonio Shopping Center
# 49                                    Ryland Park
# 50                            San Salvador at 1st
# 51                           Evelyn Park and Ride
# 52                                  St James Park
# 53                          San Jose Civic Center
# 54                  Redwood City Caltrain Station
# 55                         University and Emerson
# 56                     SJSU - San Salvador at 9th
# 57                          Washington at Kearney
# 58                       Arena Green / SAP Center
# 59                           Cowper at University
# 60                               Adobe on Almaden
# 61                         SJSU 4th at San Carlos
# 62          Rengstorff Avenue / California Street
# 63                California Ave Caltrain Station
# 64                Santa Clara County Civic Center
# 65                                  Park at Olive
# 66                       Stanford in Redwood City
# 67                                     Mezes Park
# 68                    Redwood City Medical Center
# 69                        San Mateo County Center
# 70                              Franklin at Maple
# 71                    Redwood City Public Library
# 72                               Broadway at Main
# 73                     San Jose Government Center
#
#     cantidad_de_veces_como_inicio  cantidad_de_veces_como_final
# 0                           40237                         51842
# 1                           27666                         28709
# 2                           26947                         27348
# 3                           22759                         25229
# 4                           21478                         18978
# 5                           21210                         23411
# 6                           20335                         20530
# 7                           19762                         23109
# 8                           19451                         21989
# 9                           16603                         14647
# 10                          16552                         16355
# 11                          15197                         13727
# 12                          15146                         16274
# 13                          13427                          7578
# 14                          13080                          7977
# 15                          12953                          9975
# 16                          12257                         10787
# 17                          11670                         11771
# 18                          11581                         11114
# 19                          11145                         12247
# 20                          10792                         11555
# 21                          10618                          9192
# 22                          10266                          7002
# 23                          10026                          9836
# 24                           9808                          9474
# 25                           9778                          9308
# 26                           9204                          9953
# 27                           8647                         10160
# 28                           8375                          7651
# 29                           8262                          8124
# ..                            ...                           ...
# 44                           1701                          1490
# 45                           1663                          2043
# 46                           1641                          1695
# 47                           1556                          1808
# 48                           1481                          1499
# 49                           1446                          1195
# 50                           1383                          1407
# 51                           1371                          1130
# 52                           1363                          1199
# 53                           1319                          1467
# 54                           1268                          1015
# 55                           1230                          1503
# 56                           1205                          1219
# 57                           1199                          1458
# 58                           1192                          1121
# 59                           1156                          1005
# 60                           1033                           974
# 61                            953                          1190
# 62                            936                           914
# 63                            833                           928
# 64                            699                           685
# 65                            624                           661
# 66                            352                           375
# 67                            279                           228
# 68                            264                           373
# 69                            228                           282
# 70                            177                           211
# 71                            173                           218
# 72                             55                            63
# 73                             18                            19
#
# [74 rows x 3 columns]

# %%
usos_de_estacion['usos_de_estacion'] = usos_de_estacion['cantidad_de_veces_como_inicio'] + usos_de_estacion['cantidad_de_veces_como_final']
usos_de_estacion.sort_values(by = 'usos_de_estacion', ascending = False)
# Out:
#                                          estacion  \
# 0        San Francisco Caltrain (Townsend at 4th)
# 1         San Francisco Caltrain 2 (330 Townsend)
# 2            Harry Bridges Plaza (Ferry Building)
# 3                          Embarcadero at Sansome
# 5                                 2nd at Townsend
# 7                               Market at Sansome
# 8                                 Townsend at 7th
# 6                               Steuart at Market
# 4   Temporary Transbay Terminal (Howard at Beale)
# 10                                  Market at 4th
# 12                             Powell Street BART
# 9                                  Market at 10th
# 11                              2nd at South Park
# 17              Civic Center BART (7th at Market)
# 19                                  5th at Howard
# 16                          Embarcadero at Bryant
# 15                                Beale at Market
# 18                          Embarcadero at Folsom
# 20                                  Howard at 2nd
# 14                                  2nd at Folsom
# 13                Grant Avenue at Columbus Avenue
# 23            Mechanics Plaza (Market at Battery)
# 21                       South Van Ness at Market
# 24                                Spear at Folsom
# 26  Yerba Buena Center of the Arts (3rd @ Howard)
# 25                       Commercial at Montgomery
# 27                         Embarcadero at Vallejo
# 22                  Powell at Post (Union Square)
# 30                               Davis at Jackson
# 29                                Clay at Battery
# ..                                            ...
# 46                   San Antonio Caltrain Station
# 41                             San Jose City Hall
# 43                     Palo Alto Caltrain Station
# 44               Castro Street and El Camino Real
# 48                    San Antonio Shopping Center
# 50                            San Salvador at 1st
# 53                          San Jose Civic Center
# 55                         University and Emerson
# 57                          Washington at Kearney
# 49                                    Ryland Park
# 52                                  St James Park
# 51                           Evelyn Park and Ride
# 56                     SJSU - San Salvador at 9th
# 58                       Arena Green / SAP Center
# 54                  Redwood City Caltrain Station
# 59                           Cowper at University
# 61                         SJSU 4th at San Carlos
# 60                               Adobe on Almaden
# 62          Rengstorff Avenue / California Street
# 63                California Ave Caltrain Station
# 64                Santa Clara County Civic Center
# 65                                  Park at Olive
# 66                       Stanford in Redwood City
# 68                    Redwood City Medical Center
# 69                        San Mateo County Center
# 67                                     Mezes Park
# 71                    Redwood City Public Library
# 70                              Franklin at Maple
# 72                               Broadway at Main
# 73                     San Jose Government Center
#
#     cantidad_de_veces_como_inicio  cantidad_de_veces_como_final  \
# 0                           40237                         51842
# 1                           27666                         28709
# 2                           26947                         27348
# 3                           22759                         25229
# 5                           21210                         23411
# 7                           19762                         23109
# 8                           19451                         21989
# 6                           20335                         20530
# 4                           21478                         18978
# 10                          16552                         16355
# 12                          15146                         16274
# 9                           16603                         14647
# 11                          15197                         13727
# 17                          11670                         11771
# 19                          11145                         12247
# 16                          12257                         10787
# 15                          12953                          9975
# 18                          11581                         11114
# 20                          10792                         11555
# 14                          13080                          7977
# 13                          13427                          7578
# 23                          10026                          9836
# 21                          10618                          9192
# 24                           9808                          9474
# 26                           9204                          9953
# 25                           9778                          9308
# 27                           8647                         10160
# 22                          10266                          7002
# 30                           8145                          8509
# 29                           8262                          8124
# ..                            ...                           ...
# 46                           1641                          1695
# 41                           1928                          1332
# 43                           1729                          1489
# 44                           1701                          1490
# 48                           1481                          1499
# 50                           1383                          1407
# 53                           1319                          1467
# 55                           1230                          1503
# 57                           1199                          1458
# 49                           1446                          1195
# 52                           1363                          1199
# 51                           1371                          1130
# 56                           1205                          1219
# 58                           1192                          1121
# 54                           1268                          1015
# 59                           1156                          1005
# 61                            953                          1190
# 60                           1033                           974
# 62                            936                           914
# 63                            833                           928
# 64                            699                           685
# 65                            624                           661
# 66                            352                           375
# 68                            264                           373
# 69                            228                           282
# 67                            279                           228
# 71                            173                           218
# 70                            177                           211
# 72                             55                            63
# 73                             18                            19
#
#     usos_de_estacion
# 0              92079
# 1              56375
# 2              54295
# 3              47988
# 5              44621
# 7              42871
# 8              41440
# 6              40865
# 4              40456
# 10             32907
# 12             31420
# 9              31250
# 11             28924
# 17             23441
# 19             23392
# 16             23044
# 15             22928
# 18             22695
# 20             22347
# 14             21057
# 13             21005
# 23             19862
# 21             19810
# 24             19282
# 26             19157
# 25             19086
# 27             18807
# 22             17268
# 30             16654
# 29             16386
# ..               ...
# 46              3336
# 41              3260
# 43              3218
# 44              3191
# 48              2980
# 50              2790
# 53              2786
# 55              2733
# 57              2657
# 49              2641
# 52              2562
# 51              2501
# 56              2424
# 58              2313
# 54              2283
# 59              2161
# 61              2143
# 60              2007
# 62              1850
# 63              1761
# 64              1384
# 65              1285
# 66               727
# 68               637
# 69               510
# 67               507
# 71               391
# 70               388
# 72               118
# 73                37
#
# [74 rows x 4 columns]

# %%
#Veamos ahora si la cantidad de bicis que llegan y salen de las estaciones varía según las condiciones del clima
#Veamos qué sucede cuando las temperaturas son elevadas (mayores a 25 grados C)
weather['date'] = pd.to_datetime(weather['date'])
weather['date_without_time'] = weather.date.dt.date
trip_train['start_date'] = pd.to_datetime(trip_train['start_date'])
trip_train['start_date_without_time'] = trip_train.start_date.dt.datet
high_temps = weather[(weather['max_temperature_f']>77) & (weather['max_temperature_f']<102)]
trip_train.set_index('start_date_without_time')
high_temps.set_index('date_without_time')
high_temps_trip_train = pd.merge(high_temps,trip_train,how='inner',left_index=True, right_index=True)

# %%
#Estaciones donde se retiraron mayor cantidad de bicis los días de altas temperaturas
high_temps_trip_train['start_station_name'].value_counts()
# Out:
# San Francisco Caltrain (Townsend at 4th)         52
# San Francisco Caltrain 2 (330 Townsend)          45
# Harry Bridges Plaza (Ferry Building)             39
# Embarcadero at Sansome                           35
# Townsend at 7th                                  33
# Market at Sansome                                30
# Steuart at Market                                30
# 2nd at Townsend                                  29
# Grant Avenue at Columbus Avenue                  29
# Temporary Transbay Terminal (Howard at Beale)    27
# Market at 4th                                    27
# Powell Street BART                               26
# Embarcadero at Folsom                            20
# 2nd at Folsom                                    17
# Beale at Market                                  17
# 2nd at South Park                                17
# Embarcadero at Vallejo                           16
# Market at 10th                                   15
# Civic Center BART (7th at Market)                15
# Embarcadero at Bryant                            14
# 5th at Howard                                    14
# Howard at 2nd                                    13
# Spear at Folsom                                  12
# Post at Kearny                                    9
# Mechanics Plaza (Market at Battery)               9
# Yerba Buena Center of the Arts (3rd @ Howard)     9
# Clay at Battery                                   9
# South Van Ness at Market                          9
# Broadway St at Battery St                         8
# Mountain View Caltrain Station                    8
#                                                  ..
# San Jose Diridon Caltrain Station                 6
# Davis at Jackson                                  6
# Commercial at Montgomery                          6
# Paseo de San Antonio                              5
# San Jose City Hall                                5
# Washington at Kearny                              4
# Golden Gate at Polk                               4
# San Francisco City Hall                           3
# Japantown                                         3
# Santa Clara County Civic Center                   3
# San Antonio Shopping Center                       3
# San Pedro Square                                  3
# Evelyn Park and Ride                              2
# MLK Library                                       2
# Redwood City Caltrain Station                     2
# Post at Kearney                                   2
# Ryland Park                                       2
# Mountain View City Hall                           2
# San Salvador at 1st                               1
# Stanford in Redwood City                          1
# SJSU 4th at San Carlos                            1
# Cowper at University                              1
# University and Emerson                            1
# Washington at Kearney                             1
# California Ave Caltrain Station                   1
# Redwood City Medical Center                       1
# Rengstorff Avenue / California Street             1
# SJSU - San Salvador at 9th                        1
# Redwood City Public Library                       1
# San Antonio Caltrain Station                      1
# Name: start_station_name, dtype: int64

# %%
#Estaciones donde se retiraron mayor cantidad de bicis los días de altas temperaturas (mayor a 25 grados C)
high_temps_bikes_take_out = pd.DataFrame({'cantidad de bicis retiradas en altas temperaturas' : high_temps_trip_train['start_station_name'].value_counts()}) 
high_temps_bikes_take_out.plot(kind='bar')
# Out:
# <img src="data:image/png;base64,..." width="858">

# %%
#Estaciones donde se dejaron mayor cantidad de bicis los días de altas temperaturas
high_temps_trip_train['end_station_name'].value_counts()
# Out:
# San Francisco Caltrain (Townsend at 4th)         66
# Townsend at 7th                                  40
# Embarcadero at Sansome                           35
# Steuart at Market                                33
# San Francisco Caltrain 2 (330 Townsend)          32
# Harry Bridges Plaza (Ferry Building)             31
# Market at Sansome                                30
# Temporary Transbay Terminal (Howard at Beale)    29
# 2nd at Townsend                                  27
# Powell Street BART                               25
# Embarcadero at Folsom                            18
# Market at 10th                                   17
# Mechanics Plaza (Market at Battery)              17
# Davis at Jackson                                 17
# South Van Ness at Market                         16
# 5th at Howard                                    15
# Beale at Market                                  15
# 2nd at South Park                                15
# Civic Center BART (7th at Market)                15
# 2nd at Folsom                                    15
# Market at 4th                                    14
# Broadway St at Battery St                        13
# Embarcadero at Bryant                            13
# Yerba Buena Center of the Arts (3rd @ Howard)    13
# San Jose Diridon Caltrain Station                11
# Commercial at Montgomery                         11
# Embarcadero at Vallejo                           11
# Spear at Folsom                                  11
# Powell at Post (Union Square)                    11
# Howard at 2nd                                     9
#                                                  ..
# Mountain View Caltrain Station                    5
# Post at Kearney                                   5
# Mountain View City Hall                           5
# San Pedro Square                                  4
# San Francisco City Hall                           4
# California Ave Caltrain Station                   4
# SJSU - San Salvador at 9th                        3
# Santa Clara at Almaden                            3
# University and Emerson                            3
# Palo Alto Caltrain Station                        3
# San Jose Civic Center                             3
# Castro Street and El Camino Real                  2
# San Antonio Caltrain Station                      2
# San Mateo County Center                           2
# Santa Clara County Civic Center                   2
# Paseo de San Antonio                              2
# San Jose City Hall                                2
# St James Park                                     2
# Redwood City Caltrain Station                     2
# Stanford in Redwood City                          1
# San Antonio Shopping Center                       1
# MLK Library                                       1
# Evelyn Park and Ride                              1
# Rengstorff Avenue / California Street             1
# Arena Green / SAP Center                          1
# SJSU 4th at San Carlos                            1
# Adobe on Almaden                                  1
# Japantown                                         1
# Cowper at University                              1
# Ryland Park                                       1
# Name: end_station_name, dtype: int64

# %%
#Estaciones donde se dejaron mayor cantidad de bicis los días de altas temperaturas
high_temps_bikes_drop_off = pd.DataFrame({'cantidad de bicis dejadas en altas temperaturas' : high_temps_trip_train['end_station_name'].value_counts()}) 
high_temps_bikes_drop_off.plot(kind='bar')
# Out:
# <img src="data:image/png;base64,..." width="924">

# %%
#Veamos qué sucede cuando las temperaturas son bajas (menor a 25 grados)
low_temps = weather[(weather['max_temperature_f']<77)]
low_temps.set_index('date_without_time')
low_temps_trip_train = pd.merge(low_temps,trip_train,how='inner',left_index=True, right_index=True)
low_temps_trip_train
# Out:
#            date  max_temperature_f  mean_temperature_f  min_temperature_f  \
# 0    2013-08-29               74.0                68.0               61.0
# 2    2013-08-31               71.0                64.0               57.0
# 3    2013-09-01               74.0                66.0               58.0
# 4    2013-09-02               75.0                69.0               62.0
# 5    2013-09-03               73.0                67.0               60.0
# 6    2013-09-04               74.0                68.0               61.0
# 7    2013-09-05               72.0                66.0               60.0
# 10   2013-09-08               74.0                65.0               56.0
# 11   2013-09-09               76.0                66.0               55.0
# 12   2013-09-10               74.0                66.0               57.0
# 13   2013-09-11               74.0                68.0               62.0
# 14   2013-09-12               71.0                65.0               59.0
# 15   2013-09-13               66.0                62.0               57.0
# 16   2013-09-14               66.0                62.0               57.0
# 17   2013-09-15               73.0                66.0               58.0
# 18   2013-09-16               71.0                65.0               59.0
# 19   2013-09-17               68.0                63.0               57.0
# 22   2013-09-20               73.0                65.0               56.0
# 23   2013-09-21               68.0                63.0               58.0
# 24   2013-09-22               70.0                63.0               55.0
# 26   2013-09-24               71.0                65.0               58.0
# 27   2013-09-25               67.0                62.0               56.0
# 28   2013-09-26               71.0                62.0               53.0
# 31   2013-09-29               75.0                66.0               57.0
# 32   2013-09-30               73.0                66.0               59.0
# 33   2013-10-01               69.0                63.0               56.0
# 34   2013-10-02               69.0                62.0               54.0
# 35   2013-10-03               70.0                62.0               54.0
# 36   2013-10-04               76.0                69.0               61.0
# 40   2013-10-08               72.0                62.0               52.0
# ...         ...                ...                 ...                ...
# 3567 2015-05-26               69.0                63.0               57.0
# 3568 2015-05-27               72.0                65.0               57.0
# 3569 2015-05-28               69.0                62.0               55.0
# 3570 2015-05-29               69.0                62.0               54.0
# 3571 2015-05-30               73.0                63.0               53.0
# 3572 2015-05-31               69.0                63.0               57.0
# 3573 2015-06-01               75.0                65.0               54.0
# 3574 2015-06-02               70.0                64.0               58.0
# 3575 2015-06-03               72.0                63.0               53.0
# 3576 2015-06-04               75.0                64.0               53.0
# 3582 2015-06-10               73.0                68.0               62.0
# 3586 2015-06-14               75.0                65.0               55.0
# 3587 2015-06-15               69.0                62.0               54.0
# 3588 2015-06-16               76.0                65.0               53.0
# 3590 2015-06-18               75.0                64.0               53.0
# 3593 2015-06-21               73.0                65.0               56.0
# 3594 2015-06-22               71.0                63.0               55.0
# 3600 2015-06-28               75.0                68.0               61.0
# 3610 2015-07-08               73.0                67.0               60.0
# 3611 2015-07-09               74.0                68.0               61.0
# 3612 2015-07-10               73.0                67.0               61.0
# 3613 2015-07-11               75.0                67.0               58.0
# 3614 2015-07-12               76.0                69.0               61.0
# 3616 2015-07-14               74.0                67.0               59.0
# 3623 2015-07-21               76.0                69.0               62.0
# 3625 2015-07-23               73.0                65.0               57.0
# 3627 2015-07-25               75.0                67.0               58.0
# 3635 2015-08-02               76.0                70.0               63.0
# 3637 2015-08-04               76.0                67.0               58.0
# 3653 2015-08-20               75.0                69.0               62.0
#
#       max_dew_point_f  mean_dew_point_f  min_dew_point_f  max_humidity  \
# 0                61.0              58.0             56.0          93.0
# 2                57.0              56.0             54.0          93.0
# 3                60.0              56.0             53.0          87.0
# 4                61.0              60.0             58.0          93.0
# 5                59.0              56.0             51.0          84.0
# 6                59.0              57.0             56.0          90.0
# 7                57.0              56.0             54.0          90.0
# 10               58.0              54.0             52.0          86.0
# 11               58.0              55.0             52.0          90.0
# 12               59.0              56.0             54.0          93.0
# 13               57.0              55.0             54.0          78.0
# 14               58.0              57.0             55.0          84.0
# 15               55.0              54.0             54.0          93.0
# 16               55.0              54.0             53.0          87.0
# 17               59.0              55.0             52.0          90.0
# 18               58.0              55.0             53.0          90.0
# 19               55.0              53.0             50.0          86.0
# 22               59.0              56.0             50.0          87.0
# 23               59.0              56.0             53.0          90.0
# 24               55.0              53.0             49.0          93.0
# 26               54.0              52.0             50.0          78.0
# 27               51.0              47.0             45.0          83.0
# 28               46.0              43.0             38.0          72.0
# 31               59.0              56.0             53.0          87.0
# 32               60.0              57.0             43.0          87.0
# 33               50.0              48.0             46.0          77.0
# 34               49.0              46.0             44.0          77.0
# 35               44.0              41.0             35.0          66.0
# 36               51.0              42.0             28.0          53.0
# 40               50.0              47.0             44.0          77.0
# ...               ...               ...              ...           ...
# 3567             52.0              50.0             48.0          80.0
# 3568             54.0              50.0             48.0          80.0
# 3569             54.0              51.0             49.0          86.0
# 3570             54.0              52.0             50.0          86.0
# 3571             56.0              52.0             50.0          86.0
# 3572             53.0              51.0             48.0          80.0
# 3573             55.0              52.0             47.0          78.0
# 3574             55.0              52.0             49.0          80.0
# 3575             50.0              49.0             47.0          77.0
# 3576             53.0              50.0             47.0          83.0
# 3582             65.0              61.0             59.0          87.0
# 3586             57.0              52.0             50.0          86.0
# 3587             54.0              52.0             50.0          86.0
# 3588             55.0              52.0             48.0          89.0
# 3590             55.0              50.0             45.0          89.0
# 3593             55.0              52.0             48.0          93.0
# 3594             55.0              52.0             51.0          86.0
# 3600             59.0              57.0             56.0          90.0
# 3610             57.0              54.0             53.0          84.0
# 3611             57.0              54.0             52.0          78.0
# 3612             56.0              55.0             53.0          78.0
# 3613             55.0              53.0             52.0          78.0
# 3614             56.0              54.0             52.0          73.0
# 3616             57.0              56.0             55.0          84.0
# 3623             60.0              57.0             56.0          84.0
# 3625             55.0              53.0             51.0          80.0
# 3627             58.0              56.0             53.0          86.0
# 3635             59.0              57.0             55.0          84.0
# 3637             55.0              53.0             51.0          80.0
# 3653             59.0              58.0             57.0          84.0
#
#       mean_humidity  min_humidity           ...                    end_date  \
# 0              75.0          57.0           ...              8/27/2015 8:43
# 2              75.0          57.0           ...               6/9/2014 8:47
# 3              68.0          49.0           ...             1/26/2015 17:07
# 4              77.0          61.0           ...             8/29/2015 15:14
# 5              65.0          46.0           ...             10/30/2014 7:06
# 6              72.0          53.0           ...              8/7/2015 17:17
# 7              74.0          57.0           ...             10/8/2014 14:23
# 10             70.0          53.0           ...              5/20/2014 9:12
# 11             70.0          50.0           ...             6/20/2014 11:39
# 12             73.0          53.0           ...             8/30/2014 15:52
# 13             68.0          57.0           ...              8/7/2014 10:17
# 14             73.0          61.0           ...             7/27/2015 15:25
# 15             80.0          67.0           ...              2/15/2015 9:15
# 16             77.0          67.0           ...              8/1/2014 17:06
# 17             72.0          53.0           ...             3/23/2014 17:43
# 18             74.0          57.0           ...              4/13/2014 9:55
# 19             72.0          58.0           ...              7/3/2014 17:51
# 22             70.0          53.0           ...             11/4/2014 17:46
# 23             75.0          59.0           ...              5/22/2015 7:19
# 24             70.0          47.0           ...             5/15/2015 19:00
# 26             66.0          53.0           ...             5/26/2014 13:28
# 27             64.0          45.0           ...             10/6/2014 16:18
# 28             53.0          33.0           ...             11/27/2013 7:53
# 31             70.0          53.0           ...              2/13/2014 8:52
# 32             69.0          51.0           ...             4/27/2015 18:41
# 33             61.0          45.0           ...              6/10/2014 9:02
# 34             61.0          45.0           ...             11/7/2014 16:12
# 35             47.0          28.0           ...            10/30/2014 18:34
# 36             38.0          22.0           ...             11/15/2013 6:15
# 40             59.0          41.0           ...             10/30/2014 9:31
# ...             ...           ...           ...                         ...
# 3567           68.0          55.0           ...             12/4/2013 21:38
# 3568           65.0          49.0           ...             2/22/2014 19:22
# 3569           72.0          58.0           ...              7/7/2014 18:43
# 3570           72.0          57.0           ...               2/3/2015 7:09
# 3571           70.0          53.0           ...             7/15/2014 13:55
# 3572           67.0          53.0           ...             5/12/2015 18:39
# 3573           64.0          49.0           ...            10/17/2014 15:41
# 3574           68.0          55.0           ...             6/11/2014 16:37
# 3575           62.0          47.0           ...               7/9/2015 8:10
# 3576           64.0          44.0           ...             5/29/2014 15:23
# 3582           77.0          66.0           ...             7/29/2014 19:49
# 3586           66.0          46.0           ...             1/16/2015 16:21
# 3587           72.0          58.0           ...               8/7/2015 6:58
# 3588           68.0          46.0           ...             9/20/2013 13:08
# 3590           62.0          35.0           ...             12/17/2013 7:18
# 3593           69.0          44.0           ...             11/1/2013 16:21
# 3594           70.0          53.0           ...             4/29/2015 22:11
# 3600           74.0          57.0           ...              6/19/2015 9:36
# 3610           69.0          53.0           ...             2/17/2014 12:51
# 3611           66.0          53.0           ...             4/23/2014 10:53
# 3612           68.0          57.0           ...             2/14/2015 10:44
# 3613           66.0          53.0           ...             9/13/2014 16:17
# 3614           60.0          46.0           ...             9/20/2013 13:01
# 3616           69.0          53.0           ...            12/29/2014 10:54
# 3623           69.0          54.0           ...             5/15/2015 18:07
# 3625           65.0          49.0           ...             9/23/2014 20:00
# 3627           72.0          57.0           ...              3/27/2015 8:48
# 3635           67.0          50.0           ...             9/17/2014 14:46
# 3637           63.0          46.0           ...              6/12/2015 8:51
# 3653           71.0          57.0           ...              7/11/2015 9:44
#
#                                    end_station_name  end_station_id  bike_id  \
# 0                            Embarcadero at Sansome              60      187
# 2                                     2nd at Folsom              62      281
# 3     Temporary Transbay Terminal (Howard at Beale)              55      634
# 4                                Powell Street BART              39      607
# 5          San Francisco Caltrain (Townsend at 4th)              70      370
# 6                                   2nd at Townsend              61      443
# 7          San Francisco Caltrain (Townsend at 4th)              70      485
# 10                                   Market at 10th              67      528
# 11                Civic Center BART (7th at Market)              72      284
# 12                            Embarcadero at Folsom              51      659
# 13                            Embarcadero at Folsom              51      592
# 14         San Francisco Caltrain (Townsend at 4th)              70      524
# 15                                    Market at 4th              76      325
# 16                                  2nd at Townsend              61      507
# 17             Harry Bridges Plaza (Ferry Building)              50      415
# 18                            Embarcadero at Folsom              51      344
# 19                         South Van Ness at Market              66      524
# 22                                  Townsend at 7th              65      134
# 23                         Commercial at Montgomery              45      348
# 24                                  2nd at Townsend              61      475
# 26             Harry Bridges Plaza (Ferry Building)              50      392
# 27             Harry Bridges Plaza (Ferry Building)              50      401
# 28                                 San Pedro Square               6       20
# 31                               Powell Street BART              39      557
# 32                Civic Center BART (7th at Market)              72      418
# 33                                  Townsend at 7th              65      614
# 34                                Market at Sansome              77      440
# 35                            Embarcadero at Bryant              54      320
# 36                            Embarcadero at Bryant              54      441
# 40                               Powell Street BART              39      444
# ...                                             ...             ...      ...
# 3567                                  5th at Howard              57      517
# 3568                         Embarcadero at Sansome              60      364
# 3569                                  5th at Howard              57      466
# 3570                       Commercial at Montgomery              45      212
# 3571                              Market at Sansome              77      291
# 3572                           Paseo de San Antonio               7      653
# 3573                          Embarcadero at Bryant              54      505
# 3574        San Francisco Caltrain 2 (330 Townsend)              69      592
# 3575        San Francisco Caltrain 2 (330 Townsend)              69      372
# 3576        San Francisco Caltrain 2 (330 Townsend)              69      447
# 3582                                  Howard at 2nd              63      274
# 3586           Harry Bridges Plaza (Ferry Building)              50      379
# 3587  Temporary Transbay Terminal (Howard at Beale)              55      493
# 3588                              Market at Sansome              77      575
# 3590                                Clay at Battery              41      603
# 3593              San Jose Diridon Caltrain Station               2      646
# 3594                      Broadway St at Battery St              82      567
# 3600                                 Market at 10th              67      222
# 3610            Mechanics Plaza (Market at Battery)              75      508
# 3611                              2nd at South Park              64      435
# 3612  Yerba Buena Center of the Arts (3rd @ Howard)              68      419
# 3613                                  Howard at 2nd              63      437
# 3614                               Davis at Jackson              42      331
# 3616                                  Howard at 2nd              63      480
# 3623        San Francisco Caltrain 2 (330 Townsend)              69      480
# 3625                         Embarcadero at Sansome              60      549
# 3627                     Palo Alto Caltrain Station              34      196
# 3635                         Embarcadero at Sansome              60      404
# 3637  Temporary Transbay Terminal (Howard at Beale)              55      532
# 3653  Temporary Transbay Terminal (Howard at Beale)              55      189
#
#       subscription_type  zip_code_y    weekday  deNoche  estacion  \
# 0            Subscriber       94602   Thursday        0         1
# 2            Subscriber       94107     Monday        0         0
# 3            Subscriber       94602     Monday        0         3
# 4            Subscriber       94709   Saturday        0         1
# 5            Subscriber       94107   Thursday        1         2
# 6            Subscriber       94107     Friday        0         1
# 7            Subscriber       94107  Wednesday        0         2
# 10           Subscriber       95112    Tuesday        0         0
# 11           Subscriber       94960     Friday        0         0
# 12             Customer       94952   Saturday        0         1
# 13           Subscriber       94107   Thursday        0         1
# 14           Subscriber       94107     Monday        0         1
# 15             Customer       79932     Sunday        0         3
# 16           Subscriber       94107     Friday        0         1
# 17             Customer       90717     Sunday        0         0
# 18           Subscriber       94111     Sunday        0         0
# 19           Subscriber       94612   Thursday        0         1
# 22           Subscriber       94110    Tuesday        0         2
# 23           Subscriber       94611     Friday        0         0
# 24           Subscriber       94158     Friday        0         0
# 26             Customer       92620     Monday        0         0
# 27           Subscriber       94904     Monday        0         2
# 28           Subscriber       95377  Wednesday        1         2
# 31           Subscriber       95815   Thursday        0         3
# 32           Subscriber       94103     Monday        0         0
# 33           Subscriber       94105    Tuesday        0         0
# 34             Customer       94133     Friday        0         2
# 35           Subscriber       94107   Thursday        1         2
# 36           Subscriber       94109     Friday        1         2
# 40             Customer          66   Thursday        0         2
# ...                 ...         ...        ...      ...       ...
# 3567         Subscriber       94103  Wednesday        1         2
# 3568           Customer         NaN   Saturday        0         3
# 3569         Subscriber       94107     Monday        0         1
# 3570         Subscriber       94611    Tuesday        1         3
# 3571         Subscriber       94306    Tuesday        0         1
# 3572         Subscriber       95113    Tuesday        0         0
# 3573         Subscriber       94105     Friday        0         2
# 3574         Subscriber       94158  Wednesday        0         0
# 3575         Subscriber       94103   Thursday        0         1
# 3576           Customer       94115   Thursday        0         0
# 3582         Subscriber       94103    Tuesday        0         1
# 3586         Subscriber       94501     Friday        0         3
# 3587         Subscriber       94030     Friday        1         1
# 3588           Customer       94901     Friday        0         1
# 3590         Subscriber       94062    Tuesday        1         2
# 3593         Subscriber       95377     Friday        0         2
# 3594         Subscriber       94107  Wednesday        1         0
# 3600         Subscriber       94709     Friday        0         0
# 3610         Subscriber       94117     Monday        0         3
# 3611         Subscriber       94549  Wednesday        0         0
# 3612         Subscriber       94129   Saturday        0         3
# 3613         Subscriber       94107   Saturday        0         1
# 3614           Customer       94108     Friday        0         1
# 3616         Subscriber       94063     Monday        0         3
# 3623         Subscriber       94303     Friday        0         0
# 3625         Subscriber       94117    Tuesday        0         2
# 3627         Subscriber       94301     Friday        0         0
# 3635         Subscriber       94133  Wednesday        0         1
# 3637         Subscriber       94566     Friday        0         0
# 3653           Customer        7041   Saturday        0         1
#
#      start_date_without_time
# 0                 2015-08-27
# 2                 2014-06-09
# 3                 2015-01-26
# 4                 2015-08-29
# 5                 2014-10-30
# 6                 2015-08-07
# 7                 2014-10-08
# 10                2014-05-20
# 11                2014-06-20
# 12                2014-08-30
# 13                2014-08-07
# 14                2015-07-27
# 15                2015-02-15
# 16                2014-08-01
# 17                2014-03-23
# 18                2014-04-13
# 19                2014-07-03
# 22                2014-11-04
# 23                2015-05-22
# 24                2015-05-15
# 26                2014-05-26
# 27                2014-10-06
# 28                2013-11-27
# 31                2014-02-13
# 32                2015-04-27
# 33                2014-06-10
# 34                2014-11-07
# 35                2014-10-30
# 36                2013-11-15
# 40                2014-10-30
# ...                      ...
# 3567              2013-12-04
# 3568              2014-02-22
# 3569              2014-07-07
# 3570              2015-02-03
# 3571              2014-07-15
# 3572              2015-05-12
# 3573              2014-10-17
# 3574              2014-06-11
# 3575              2015-07-09
# 3576              2014-05-29
# 3582              2014-07-29
# 3586              2015-01-16
# 3587              2015-08-07
# 3588              2013-09-20
# 3590              2013-12-17
# 3593              2013-11-01
# 3594              2015-04-29
# 3600              2015-06-19
# 3610              2014-02-17
# 3611              2014-04-23
# 3612              2015-02-14
# 3613              2014-09-13
# 3614              2013-09-20
# 3616              2014-12-29
# 3623              2015-05-15
# 3625              2014-09-23
# 3627              2015-03-27
# 3635              2014-09-17
# 3637              2015-06-12
# 3653              2015-07-11
#
# [2739 rows x 40 columns]

# %%
#Estaciones donde se retiraron mayor cantidad de bicis los días de temperaturas bajas
low_temps_trip_train['start_station_name'].value_counts()
# Out:
# San Francisco Caltrain (Townsend at 4th)         188
# San Francisco Caltrain 2 (330 Townsend)          151
# Harry Bridges Plaza (Ferry Building)             131
# Townsend at 7th                                  116
# Steuart at Market                                110
# 2nd at Townsend                                  108
# Temporary Transbay Terminal (Howard at Beale)    107
# Embarcadero at Sansome                            97
# Market at Sansome                                 93
# Market at 10th                                    90
# Market at 4th                                     84
# 2nd at South Park                                 81
# Beale at Market                                   76
# Embarcadero at Folsom                             69
# 2nd at Folsom                                     66
# Powell Street BART                                63
# Grant Avenue at Columbus Avenue                   63
# 5th at Howard                                     59
# Powell at Post (Union Square)                     57
# South Van Ness at Market                          55
# Civic Center BART (7th at Market)                 54
# Mechanics Plaza (Market at Battery)               52
# Embarcadero at Bryant                             51
# Howard at 2nd                                     51
# Broadway St at Battery St                         50
# Yerba Buena Center of the Arts (3rd @ Howard)     49
# Post at Kearny                                    47
# Embarcadero at Vallejo                            45
# Spear at Folsom                                   45
# San Jose Diridon Caltrain Station                 39
#                                                 ...
# University and Emerson                             9
# Redwood City Caltrain Station                      9
# San Pedro Square                                   9
# Ryland Park                                        9
# San Jose City Hall                                 9
# Arena Green / SAP Center                           8
# Castro Street and El Camino Real                   8
# Post at Kearney                                    8
# Paseo de San Antonio                               7
# Palo Alto Caltrain Station                         7
# MLK Library                                        7
# California Ave Caltrain Station                    6
# San Jose Civic Center                              6
# San Antonio Shopping Center                        6
# Cowper at University                               6
# SJSU - San Salvador at 9th                         5
# San Salvador at 1st                                5
# San Antonio Caltrain Station                       4
# St James Park                                      4
# Rengstorff Avenue / California Street              4
# Washington at Kearney                              3
# SJSU 4th at San Carlos                             3
# Stanford in Redwood City                           2
# Franklin at Maple                                  2
# Redwood City Public Library                        2
# Broadway at Main                                   1
# Santa Clara County Civic Center                    1
# Park at Olive                                      1
# Redwood City Medical Center                        1
# Adobe on Almaden                                   1
# Name: start_station_name, dtype: int64

# %%
#Estaciones donde se retiraron mayor cantidad de bicis los días de temperaturas bajas
low_temps_bikes_take_out = pd.DataFrame({'cantidad de bicis retiradas en bajas temperaturas' : low_temps_trip_train['start_station_name'].value_counts()}) 
low_temps_bikes_take_out.plot(kind='bar')
# Out:
# <img src="data:image/png;base64,..." width="968">

# %%
#Estaciones donde se dejaron mayor cantidad de bicis los días de temperaturas bajas
low_temps_trip_train['end_station_name'].value_counts()
# Out:
# San Francisco Caltrain (Townsend at 4th)         254
# Harry Bridges Plaza (Ferry Building)             141
# San Francisco Caltrain 2 (330 Townsend)          132
# Embarcadero at Sansome                           132
# Market at Sansome                                124
# 2nd at Townsend                                  119
# Steuart at Market                                106
# Temporary Transbay Terminal (Howard at Beale)    100
# Townsend at 7th                                   95
# Powell Street BART                                86
# Market at 4th                                     85
# Market at 10th                                    75
# 5th at Howard                                     67
# 2nd at South Park                                 64
# Civic Center BART (7th at Market)                 62
# Yerba Buena Center of the Arts (3rd @ Howard)     59
# Mechanics Plaza (Market at Battery)               57
# South Van Ness at Market                          53
# Spear at Folsom                                   53
# Embarcadero at Folsom                             53
# Embarcadero at Vallejo                            50
# Howard at 2nd                                     49
# Embarcadero at Bryant                             48
# Commercial at Montgomery                          46
# Broadway St at Battery St                         46
# Beale at Market                                   44
# 2nd at Folsom                                     43
# Davis at Jackson                                  39
# Grant Avenue at Columbus Avenue                   35
# Clay at Battery                                   32
#                                                 ...
# San Salvador at 1st                               11
# Castro Street and El Camino Real                  10
# Palo Alto Caltrain Station                        10
# University and Emerson                            10
# Japantown                                          8
# Santa Clara County Civic Center                    8
# San Antonio Caltrain Station                       7
# MLK Library                                        7
# San Jose Civic Center                              7
# San Antonio Shopping Center                        6
# Paseo de San Antonio                               6
# Evelyn Park and Ride                               6
# Washington at Kearney                              6
# SJSU - San Salvador at 9th                         6
# Arena Green / SAP Center                           6
# Redwood City Caltrain Station                      5
# California Ave Caltrain Station                    5
# San Jose City Hall                                 5
# Adobe on Almaden                                   5
# SJSU 4th at San Carlos                             4
# St James Park                                      4
# Cowper at University                               4
# Ryland Park                                        3
# Rengstorff Avenue / California Street              3
# Redwood City Medical Center                        3
# Stanford in Redwood City                           2
# Redwood City Public Library                        2
# Franklin at Maple                                  2
# Mezes Park                                         1
# San Mateo County Center                            1
# Name: end_station_name, dtype: int64

# %%
#Estaciones donde se dejaron mayor cantidad de bicis los días de temperaturas bajas
low_temps_bikes_drop_off = pd.DataFrame({'cantidad de bicis dejadas en bajas temperaturas' : low_temps_trip_train['end_station_name'].value_counts()}) 
low_temps_bikes_drop_off.plot(kind='bar')
# Out:
# <img src="data:image/png;base64,..." width="956">

# %%
#Analicemos ahora para los días en los que hubo lluvias y en los que no llovió
#Veamos cuales son las estaciones con mayor movimiento de bicis dada esta condición climática
weather['precipitation_inches']=pd.to_numeric(weather['precipitation_inches'], errors='coerce')
rainy_weather = weather[(weather['precipitation_inches'] > 0) ]
rainy_weather.set_index('date_without_time')
rain_trip_train = pd.merge(rainy_weather,trip_train,how='inner',left_index=True, right_index=True)

# %%
#Estaciones donde se retiraron mayor cantidad de bicis los días de lluvias
rain_trip_train['start_station_name'].value_counts()
# Out:
# San Francisco Caltrain (Townsend at 4th)         24
# San Francisco Caltrain 2 (330 Townsend)          17
# Embarcadero at Folsom                            15
# 2nd at Townsend                                  14
# 2nd at South Park                                13
# Embarcadero at Sansome                           11
# Steuart at Market                                11
# Market at Sansome                                11
# Market at 4th                                    10
# Townsend at 7th                                   9
# Powell at Post (Union Square)                     8
# 2nd at Folsom                                     8
# Beale at Market                                   8
# 5th at Howard                                     8
# Powell Street BART                                7
# Harry Bridges Plaza (Ferry Building)              7
# Market at 10th                                    7
# Clay at Battery                                   6
# Embarcadero at Bryant                             6
# Temporary Transbay Terminal (Howard at Beale)     6
# Grant Avenue at Columbus Avenue                   6
# Commercial at Montgomery                          6
# Broadway St at Battery St                         5
# Spear at Folsom                                   5
# Post at Kearny                                    5
# South Van Ness at Market                          5
# Howard at 2nd                                     4
# San Jose Diridon Caltrain Station                 4
# Civic Center BART (7th at Market)                 4
# Mountain View Caltrain Station                    4
# Evelyn Park and Ride                              3
# Mechanics Plaza (Market at Battery)               3
# Golden Gate at Polk                               3
# Yerba Buena Center of the Arts (3rd @ Howard)     3
# University and Emerson                            2
# San Salvador at 1st                               2
# Washington at Kearny                              2
# San Francisco City Hall                           2
# Washington at Kearney                             2
# Embarcadero at Vallejo                            2
# Ryland Park                                       2
# Japantown                                         1
# San Jose City Hall                                1
# San Pedro Square                                  1
# Redwood City Medical Center                       1
# Palo Alto Caltrain Station                        1
# Davis at Jackson                                  1
# SJSU 4th at San Carlos                            1
# Mountain View City Hall                           1
# San Jose Civic Center                             1
# San Antonio Caltrain Station                      1
# Name: start_station_name, dtype: int64

# %%
#Estaciones donde se retiraron mayor cantidad de bicis los días de lluvias
rain_trip_train_bikes_take_out = pd.DataFrame({'cantidad de bicis retiradas en días de lluvia' : rain_trip_train['start_station_name'].value_counts()}) 
rain_trip_train_bikes_take_out.plot(kind='bar')
# Out:
# <img src="data:image/png;base64,..." width="991">

# %%
#Estaciones donde se dejaron mayor cantidad de bicis los días sin lluvias
rain_trip_train['end_station_name'].value_counts()
# Out:
# San Francisco Caltrain (Townsend at 4th)         27
# Harry Bridges Plaza (Ferry Building)             20
# San Francisco Caltrain 2 (330 Townsend)          15
# Embarcadero at Sansome                           14
# Market at Sansome                                14
# Market at 4th                                    13
# Steuart at Market                                13
# 2nd at Townsend                                  11
# Townsend at 7th                                  10
# Market at 10th                                   10
# Temporary Transbay Terminal (Howard at Beale)     8
# Howard at 2nd                                     7
# Embarcadero at Folsom                             7
# Commercial at Montgomery                          7
# Davis at Jackson                                  7
# 2nd at South Park                                 7
# Broadway St at Battery St                         6
# Beale at Market                                   5
# Embarcadero at Bryant                             5
# Clay at Battery                                   5
# 5th at Howard                                     5
# Spear at Folsom                                   5
# Civic Center BART (7th at Market)                 5
# Mechanics Plaza (Market at Battery)               4
# Santa Clara at Almaden                            4
# Powell Street BART                                4
# Powell at Post (Union Square)                     4
# Mountain View Caltrain Station                    4
# Yerba Buena Center of the Arts (3rd @ Howard)     4
# Embarcadero at Vallejo                            3
# University and Emerson                            3
# Golden Gate at Polk                               3
# South Van Ness at Market                          3
# Post at Kearney                                   3
# Grant Avenue at Columbus Avenue                   3
# Post at Kearny                                    2
# Castro Street and El Camino Real                  2
# San Pedro Square                                  2
# San Jose Diridon Caltrain Station                 2
# Washington at Kearny                              2
# San Salvador at 1st                               2
# Washington at Kearney                             2
# San Mateo County Center                           1
# SJSU - San Salvador at 9th                        1
# Evelyn Park and Ride                              1
# Rengstorff Avenue / California Street             1
# San Francisco City Hall                           1
# Santa Clara County Civic Center                   1
# Mountain View City Hall                           1
# Ryland Park                                       1
# Name: end_station_name, dtype: int64

# %%
#Estaciones donde se retiraron mayor cantidad de bicis los días de lluvias

rain_trip_train_bikes_drop_off = pd.DataFrame({'cantidad de bicis dejadas en días de lluvia' : rain_trip_train['end_station_name'].value_counts()}) 
rain_trip_train_bikes_drop_off.plot(kind='bar')
# Out:
# <img src="data:image/png;base64,..." width="995">

# %%
#Datos sin lluvia
#Veamos cuales son las estaciones con mayor movimiento de bicis 
no_rain_weather = weather[(weather['precipitation_inches'] == 0) ]
no_rain_weather.set_index('date_without_time')
no_rain_trip_train = pd.merge(rainy_weather,trip_train,how='inner',left_index=True, right_index=True)

# %%
#Estaciones donde se retiraron mayor cantidad de bicis los días sin lluvias
no_rain_trip_train['start_station_name'].value_counts()
# Out:
# San Francisco Caltrain (Townsend at 4th)         24
# San Francisco Caltrain 2 (330 Townsend)          17
# Embarcadero at Folsom                            15
# 2nd at Townsend                                  14
# 2nd at South Park                                13
# Embarcadero at Sansome                           11
# Steuart at Market                                11
# Market at Sansome                                11
# Market at 4th                                    10
# Townsend at 7th                                   9
# Powell at Post (Union Square)                     8
# 2nd at Folsom                                     8
# Beale at Market                                   8
# 5th at Howard                                     8
# Powell Street BART                                7
# Harry Bridges Plaza (Ferry Building)              7
# Market at 10th                                    7
# Clay at Battery                                   6
# Embarcadero at Bryant                             6
# Temporary Transbay Terminal (Howard at Beale)     6
# Grant Avenue at Columbus Avenue                   6
# Commercial at Montgomery                          6
# Broadway St at Battery St                         5
# Spear at Folsom                                   5
# Post at Kearny                                    5
# South Van Ness at Market                          5
# Howard at 2nd                                     4
# San Jose Diridon Caltrain Station                 4
# Civic Center BART (7th at Market)                 4
# Mountain View Caltrain Station                    4
# Evelyn Park and Ride                              3
# Mechanics Plaza (Market at Battery)               3
# Golden Gate at Polk                               3
# Yerba Buena Center of the Arts (3rd @ Howard)     3
# University and Emerson                            2
# San Salvador at 1st                               2
# Washington at Kearny                              2
# San Francisco City Hall                           2
# Washington at Kearney                             2
# Embarcadero at Vallejo                            2
# Ryland Park                                       2
# Japantown                                         1
# San Jose City Hall                                1
# San Pedro Square                                  1
# Redwood City Medical Center                       1
# Palo Alto Caltrain Station                        1
# Davis at Jackson                                  1
# SJSU 4th at San Carlos                            1
# Mountain View City Hall                           1
# San Jose Civic Center                             1
# San Antonio Caltrain Station                      1
# Name: start_station_name, dtype: int64

# %%
#Estaciones donde se retiraron mayor cantidad de bicis los días de lluvias

no_rain_trip_train_bikes_take_out = pd.DataFrame({'cantidad de bicis retiradas en días de lluvia' : no_rain_trip_train['start_station_name'].value_counts()}) 
no_rain_trip_train_bikes_take_out.plot(kind='bar')
# Out:
# <img src="data:image/png;base64,..." width="1023">

# %%
#Estaciones donde se dejaron mayor cantidad de bicis los días sin lluvias
no_rain_trip_train['end_station_name'].value_counts()
# Out:
# San Francisco Caltrain (Townsend at 4th)         27
# Harry Bridges Plaza (Ferry Building)             20
# San Francisco Caltrain 2 (330 Townsend)          15
# Embarcadero at Sansome                           14
# Market at Sansome                                14
# Market at 4th                                    13
# Steuart at Market                                13
# 2nd at Townsend                                  11
# Townsend at 7th                                  10
# Market at 10th                                   10
# Temporary Transbay Terminal (Howard at Beale)     8
# Howard at 2nd                                     7
# Embarcadero at Folsom                             7
# Commercial at Montgomery                          7
# Davis at Jackson                                  7
# 2nd at South Park                                 7
# Broadway St at Battery St                         6
# Beale at Market                                   5
# Embarcadero at Bryant                             5
# Clay at Battery                                   5
# 5th at Howard                                     5
# Spear at Folsom                                   5
# Civic Center BART (7th at Market)                 5
# Mechanics Plaza (Market at Battery)               4
# Santa Clara at Almaden                            4
# Powell Street BART                                4
# Powell at Post (Union Square)                     4
# Mountain View Caltrain Station                    4
# Yerba Buena Center of the Arts (3rd @ Howard)     4
# Embarcadero at Vallejo                            3
# University and Emerson                            3
# Golden Gate at Polk                               3
# South Van Ness at Market                          3
# Post at Kearney                                   3
# Grant Avenue at Columbus Avenue                   3
# Post at Kearny                                    2
# Castro Street and El Camino Real                  2
# San Pedro Square                                  2
# San Jose Diridon Caltrain Station                 2
# Washington at Kearny                              2
# San Salvador at 1st                               2
# Washington at Kearney                             2
# San Mateo County Center                           1
# SJSU - San Salvador at 9th                        1
# Evelyn Park and Ride                              1
# Rengstorff Avenue / California Street             1
# San Francisco City Hall                           1
# Santa Clara County Civic Center                   1
# Mountain View City Hall                           1
# Ryland Park                                       1
# Name: end_station_name, dtype: int64

# %%
#Estaciones donde se dejaronmayor cantidad de bicis los días de lluvias
no_rain_trip_train_bikes_drop_of = pd.DataFrame({'cantidad de bicis dejadas en días de lluvia' : no_rain_trip_train['end_station_name'].value_counts()}) 
no_rain_trip_train_bikes_drop_of.plot(kind='bar')
# Out:
# <img src="data:image/png;base64,..." width="987">
